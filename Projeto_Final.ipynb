# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasllimati/imersao-dados-alura/blob/main/Projeto_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Semana Imersão dados da Alura

# %% [markdown]
# ## Contato

# %% [markdown]
# **Por:** Lucas Lima<br>
# **Github:** https://www.linkedin.com/in/lucasllimati/<br>
# **LinkedIn:** https://github.com/lucasllimati

# %% [markdown]
# # Aula 1

# %% [markdown]
# Seja bem-vindo e bem-vinda à primeira aula da Imersão Dados 3ª Edição!
#
# Preparamos a aula para não precisar instalar nada em sua máquina. Você só precisa acessar o Google Colab e iniciar o desenvolvimento do projeto.
#
# Nesta aula teremos nosso primeiro contato com Python e a famosa biblioteca Pandas, utilizando diversas funcionalidades da mesma para explorar dados do ramo de Drug Discovery. Durante nossa análise de dados, vamos descobrir fatores importantes para a obtenção de insights e também aprenderemos como plotar os gráficos de pizza e de colunas discutindo pontos positivos e negativos, finalizando a aula cheia de desafios.

# %% [markdown]
# Nessa imersão vamos explorar o universo da biologia e da biotecnologia e explorar uma base de dados nesse ramo.
#
# Github da Alura com a fonte de dados: https://github.com/alura-cursos/imersaodados3/tree/main/dados

# %%
# Importação das bibliotecas
import pandas as pd
import matplotlib.pyplot as plt

# %%
# URL base de dados
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

# Importaçã da base de dados (arquivo comprimido)
dados = pd.read_csv(url_dados, compression = 'zip')

# Exibir dados
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# Imprimimos todas as nossas linhas e colunas da nossa tabela para termos um primeiro contato com o DataFrame.
#
# Aqui observamos que temos dados referentes a ID, tratamento, tempo, dose, entre outras.

# %% [markdown]
# Análise exploratória
# Nessa parte do código vamos obter algumas informações sobre os dados.

# %%
# Imprime um resumo do DataFrame, este método imprime informações o índice dtype e coluna dtypes, valores não nulos e uso de memória.
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 877 entries, id to c-99
# dtypes: float64(872), int64(1), object(4)
# memory usage: 159.3+ MB

# %%
# Imprime alguns detalhes estatísticos básicos como percentil, média, padrão, etc.
dados.describe()
# Out:
#               tempo           g-0  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %% [markdown]
# Quanto utilizamos esse comando verificamos as 5 primeiras linhas (cabeçalho) deste dataframe

# %%
# Cabeçalho da base de dados (5 primeiras linhas)
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# Agora iremos verificar a quantidade de linhas e colunas desse DataFrame

# %%
# Linhas e colunas da base de dados
dados.shape
# Out:
# (23814, 877)

# %%
# Analise da serie do dataframe, ou seja, uma coluna da base de dados
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %% [markdown]
# Anotações
#
# **TRATAMENTO**: "Se é da droga ou não é da droga".
#
# Ex: *Comparar duas propagandas com cidaddes diferentes, varáveis diferentes. Controlar todas as variáveis.*
#
# **Colunas G e C**: *Estão relacionadas as efeitos do experimento.*

# %% [markdown]
# Valores das colunas

# %% [markdown]
# Esse tipo de informação da coluna, é o que chamamos de 'série'.
#
# Já a tabela inteira nós chamos de 'dataframe'.
#
# Agora vamos os valores que estão presentes em algumas colunas.

# %%
# Valores únicos da serie 'TRATAMENTO'
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %% [markdown]
# Encontramos 3 tipos de informação nessa coluna: **24**, **48** e **72**. O que pode nos indicar o tempo, provavelmente em horas, de intervalo que foi administrada a dose de medicamentos ou drogas.

# %%
# Tempo em horas sobre a exposição / tratamento
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
# Tipos de dose (Pode ser uma diferença na quantidade das doses)
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %% [markdown]
# O resultado dessa coluna é somente **d1** e **d2**, porém não conseguimos identificar a diferença entra elas.

# %%
# Tipos de droga "Dados Anonimizados"
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %% [markdown]
# O trecho ```dados['droga'].unique()``` apresenta uma série de códigos como resultado. Possivelmente esses valores foram codificados/camuflados para anonimizar as drogas, para evitar qualquer "*preconceito*" análise dos resultados.
#
# Há uma série de regras quando alguns experimentos são feitos, evitando mostrar dados como nome, sexo, e outros fatores, dependendo da análise a ser feita.

# %%
# Amostra g-0
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %% [markdown]
# Analisando esse resultado fica difícil tentar identificar o significado desses números. Então, com o auxílio da Vanessa, especialista, conseguimos a informação que essa letra 'g' da coluna remete à palavra gene. Ou seja, esses números nos dizem a expressão de cada gene frente as drogas ou a exposição.
#
# Quando subimos de volta na tabela, percebemos que há diversos valores, inclusive com várias casas decimais. Aparentemente esses números foram "arredondados"/normalizados.
#
# Então o momento, já conseguimos identificar as informações de diferentes colunas, que nos indicam os tratamentos, as drogas, o tempo, e depois as respostas genéticas, que tem a letra g no ínicio do seu nome.

# %% [markdown]
# Contando os valores

# %% [markdown]
# Agora, o objetivo é contar a quantidade o de valores que aparece nas colunas com a função ```.value_counts```.

# %%
# Quantidade de tratamento "COM DROGAS" e "SEM DROGAS"
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
# Quantidade de tempo
dados['tempo'].value_counts()
# Out:
# 48    8250
# 72    7792
# 24    7772
# Name: tempo, dtype: int64

# %%
# Quantidade de doses
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
# Quantidade de drogas
dados['droga'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# ba08ac4bc       1
# 89ced6383       1
# ed81f4046       1
# ae2afcf9d       1
# 27fa72002       1
# Name: droga, Length: 3289, dtype: int64

# %% [markdown]
# Normalizando os dados (Proporção dos dados)

# %%
# Proporção de tratamento
# O parametro 'normalize' serve para remodelar colunas numéricas para uma escala padrão
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# Podemos notar que os resultados representam 92,16%  dos experimentos utilizando droga e 7,84% que não utilizaram droga.

# %%
# Proporção de doses
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %% [markdown]
# Agora se fizermos a mesma analise com as doses, podemos verificar que 51,00% seria com a dose **D1** e 49,00% com a dose **D2**.

# %% [markdown]
# Gráficos

# %%
# Platando gráfico de tratamento
dados['tratamento'].value_counts().plot.pie()

# %% [markdown]
# **Gráfico de pizza, não é recomendado para esse tipo de análise, pois dificulta a interpretação.
# Não é recomendado para comparação/proporção.**

# %%
# Platando gráfico de tempo 
dados['tempo'].value_counts().plot.pie()

# %%
# Platando gráfico de tempo 
dados['tempo'].value_counts().plot.bar()
plt.title('Análise quantitativa de tempo nas experimentos')
plt.xlabel('Tempo')
plt.ylabel('Quantidade')
# Out:
# Text(0, 0.5, 'Quantidade')

# %%
# Plotando gráfico de barras com matplotlib.
plt.figure(figsize=(10, 7))
cd = dados['tempo'].value_counts().plot.bar()
plt.title('Tempos de experimento', fontsize=16, fontweight='bold')
plt.xlabel('Tempo', fontsize=14, fontweight='bold')
plt.ylabel('Frequência', fontsize=14, fontweight='bold')

plt.tick_params(axis='x', labelsize=14)
plt.tick_params(axis='y', labelsize=14)

for indice, p in enumerate(cd.patches):
  cd.text(x = indice, y = p.get_height() + .5, s = str(p.get_height()), ha = 'center', fontsize = 14, fontweight = 'bold')
plt.show()

# %% [markdown]
# Filtrando dados

# %%
# Filtro de g-0: quando o valor é maior que 0.
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# ## Desafios

# %% [markdown]
# ###Desafios 01: Investigar por que a classe tratamento é tão desbalanceada?

# %% [markdown]
# Primeiro, vamos entender o que é um experimento de controle. Esse é um tipo de teste que é **feito sob condições controladas**, ou seja, que apenas um (ou poucos) fatores são alterados a cada vez, enquanto todos os outros são mantidos constantes.
# Quando nos aprofundamos um pouco na análise dos dados **`com_controle`**, percebemos que a droga ***cacb2b860*** está presente em todos eles, podemos presumir que seja devido a não adição de outras drogas na cultura de células, sendo assim, ao utilizar os mesmo experimentos de controle, pode-se diminuir o número desse experimentos que serão realizados.

# %%
#verificação de dados
# isna() -> usado na detecção de valores perdidos/nulos
dados['droga'].isna().value_counts()
# Out:
# False    23814
# Name: droga, dtype: int64

# %%
controle = dados.query('tratamento == "com_controle"')
controle
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# 47     id_008a986b7  com_controle     48   D2  ... -0.4979  0.5281 -0.9245 -0.9367
# 63     id_009d8340f  com_controle     24   D2  ...  0.0949  0.2000 -0.4326  0.9364
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23729  id_ff1f9e5fc  com_controle     24   D1  ...  0.2131 -0.1419 -0.2422  0.0457
# 23747  id_ff469c482  com_controle     72   D1  ... -0.9630  0.8872 -0.0742 -0.6777
# 23768  id_ff89331ca  com_controle     72   D2  ...  0.9517 -0.8110 -0.1748 -0.3626
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# ...

# %% [markdown]
# ###Desafios 02: Plotar as 5 últimas linhas da tabela.

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# O comando **`.tail()`** exibe as últimas 5 linhas da tabela
# head = cabeça/começo
# tail = cauda/fim

# %% [markdown]
# ###Desafios 03: Proporção das classes tratamento.

# %%
proporcao_droga = dados['tratamento'].value_counts()[0] / dados['tratamento'].value_counts().sum()*100
proporcao_controle = dados['tratamento'].value_counts()[1] / dados['tratamento'].value_counts().sum()*100
                                                             
print(f'A proporção com droga é de {proporcao_droga:.2f}%\nA propoção com controle é {proporcao_controle:.2f}%')

#O mesmo resultado pode ser obtido com (dados['tratamento'].value_counts(normalize=True)*100)
# Out:
# A proporção com droga é de 92.16%
# A propoção com controle é 7.84%

# %% [markdown]
# ### Desafios 04: Quantos tipos de drogras foram investigados.

# %%
print('Foram investigados {} tipos de drogas'.format(dados.droga.value_counts().shape[0]))
# Out:
# Foram investigados 3289 tipos de drogas

# %% [markdown]
# ### Desafios 05: Procurar na documentação o método query(pandas).

# %% [markdown]
# Com o **`query`** da bíbliotca pandas você pode consultar as colunas de um dataframe com uma expressão booleana
#
# Exemplo de como usar:
# ```
# DataFrame.query(expr, inplace=False, **kwargs)
# ```

# %% [markdown]
# ### Desafios 06: Renomear as colunas tirando o hífen.

# %%
dados.columns = dados.columns.str.replace("-", "")
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# ### Desafios 07: Deixar os gráficos mais bonitos, colocar título, eixos/label dos gráficos. (Matplotlib.pyplot).

# %%
cores = ['gold', 'darkblue']
dados['tratamento'].value_counts().plot.pie(title='Comparação entre com droga e com controle', colors=cores, figsize=(10,6))

# %%
dados['tempo'].value_counts().plot.bar(title='Comparação de tempo', color='purple', figsize=(10,4))

# %% [markdown]
# ### Desafios 08: Resumo do que você aprendeu.

# %% [markdown]
# Acredito que não tenha sido só eu que ficou com um leve receio de não entender nada do que foi explicado, mas com a equipe da Alura tudo fica mais fácil.
# Nessa aula aprendemos como importar e utilizar algumas bibliotecas como ***Pandas*** e o ***Matplotlib*** que servem para fazer uma análise exploratória dos dados que temos, nesse caso, sobre um experimento com uso de culturas de células para testar diferentes tipos de drogas.
# Ao todo temos: 3 drogas, 2 dosagem e 3 intervalos de tempo, além disso, também aprendemos a exibir os dados em formas de gráfico, que particularmente acho bem mais simples para as informações serem visualizadas.
# Outro ponto da aula foi a parte de biologia, onde aprendemos ou para alguns apenas relembramos, como as células são constituidas, contendo a Membrana Plasmática que dentro dela está o Núcleo e dentro do núcleo temos o DNA que é basicamente fragmentos de genes que sintetizam as proteínas (fora do núcleo) e são transposrtadas pelo RNA mensageiro, que normalmente possui 4 fitas.
# A quantidade de fitas pode variar dependendo do estímulo que recebe, podendo virar 8 fitas (4 x 2) ou regredir para apenas 2 (4 X 0,5).

# %% [markdown]
# #Aula 2

# %% [markdown]
# Seja bem-vindo e bem-vinda à segunda aula da Imersão Dados 3ª Edição!
#
# Nesta aula aprenderemos a plotar e estilizar gráficos com as bibliotecas seaborn e matplotlib, utilizando recursos de seleção e tratamentos nos dados. Conhecemos o histograma para visualizar a média dos genes, utilizando a função describe para descrever estatisticamente os dados. Por fim, entendemos o boxplot e como tratar os outliers.

# %% [markdown]
# Alteração do nome da coluna droga por composto.
#
# `inplace=True`:  Altera o nome da coluna na base de dados original

# %%
# Alteração do nome da coluna
mapa = {'droga' : 'composto'}
dados.rename(columns=mapa, inplace=True)

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
# 5 primeiros compostos. Da posição 0 até 4. Index pega os valores e adiciona em uma lista.
cod_compostos = dados['composto'].value_counts().index[0:5]

# %%
# Exibindo a kusta de compostos, ao qual foi utilizado a função `index`
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
# Quando o composto estiver contido em cod_compostos
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
# Biblioteca Seaborn - 
import seaborn as sns
import matplotlib.pyplot as plt
# Salvar as configurações de imagens padrões do Seaborn
sns.set()
plt.figure(figsize=(8, 6))

ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'))
# Colocar o título do gráfico
ax.set_title('Top 5 compostos')
# Tirar as informações do gráfico, texto padrão do gráfico.
plt.show()

# %%
# Nos passoa anteriores foi retirado o hífen '-', por esse motivo foi atualizado a coluna no código abaixo.
#dados['g-0'].unique()
len(dados['g0'].unique())
# Out:
# 14367

# %%
# Valor mínimo da coluna d0
dados['g0'].min()
# Out:
# -5.513

# %%
# Valor máximo da coluna d0
dados['g0'].max()
# Out:
# 10.0

# %%
# dados['g0'].hist(bins = 50)
dados['g0'].hist(bins = 100)

# %%
dados['g19'].hist(bins = 100)

# %%
# dados['g0'].mean()
dados.describe()
# Out:
#               tempo            g0  ...           c98           c99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados[['g0', 'g1']]
# Out:
#            g0      g1
# 0      1.0620  0.5577
# 1      0.0743  0.4087
# 2      0.6280  0.5817
# 3     -0.5138 -0.2491
# 4     -0.3254 -0.4009
# ...       ...     ...
# 23809  0.1394 -0.0636
# 23810 -1.3260  0.3478
# 23811  0.3942  0.3756
# 23812  0.6660  0.2324
# 23813 -0.8598  1.0240
#
# [23814 rows x 2 columns]

# %%
# Descrevendo os valores de todas as colunas Gs (da g0 até d771). Os `:` seria para pegar do primeiro ao último elemento
dados.loc[:, 'g0':'g771'].describe()
# Out:
#                  g0            g1  ...          g770          g771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
# `.T`:Transpor matriz (colunas em linhas)
# histograma da média
dados.loc[:, 'g0':'g771'].describe().T['mean'].hist(bins=30)

# %%
# histograma do minimo
dados.loc[:, 'g0':'g771'].describe().T['min'].hist(bins=30)

# %%
# histograma do máximo
dados.loc[:, 'g0':'g771'].describe().T['max'].hist(bins=30)

# %%
# celular saudaveis e também cancerigenas (por exemplo).
dados.loc[:, 'c0':'c99'].describe().T['mean'].hist(bins=50)

# %%
sns.boxplot(x='g0', data=dados)

# %%
sns.boxplot(x='g0', y='tratamento' , data=dados)

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x='tratamento', y='g0' , data=dados)

# %% [markdown]
# ## Desafios

# %% [markdown]
# ### Desafios 01: Ordenar o gráfico countplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Salvar as configurações de imagens padrões do Seaborn
sns.set()
plt.figure(figsize=(8, 6))

ax = sns.countplot(x = 'composto', data = dados.query('composto in @cod_compostos'), order=cod_compostos)

# Colocar o título do gráfico
ax.set_title('Top 5 compostos')
# Tirar as informações do gráfico, texto padrão do gráfico.
plt.show()

# %% [markdown]
# ### Desafios 02: Melhorar o visualização alterando o tamanho da fonte...

# %%
plt.figure(figsize = (10,8)) # Ajustado o tamanho do gráfico
ax = sns.countplot(x = 'composto', data = dados.query('composto in @cod_compostos'), palette = "crest", order = cod_compostos)
ax.set_title('Top 5 Compostos', fontsize=18) # Colocando um título e ajustando a fonte do título
ax.set_xlabel('Nome dos Compostos', fontsize = 16) # Coloando a legenda do eixo x e ajustando sua fonte
ax.set_ylabel('Contagem dos Elementos', fontsize = 16) # Colocando a legenda do eixo y e ajustando sua fonte
plt.show() # Mostra o gráfico sem algumas informações que vem acima dele que não são necessárias

# %% [markdown]
# ### Desafios 03: Plotar os histogramas com seaborn

# %% [markdown]
# Site: https://seaborn.pydata.org/generated/seaborn.histplot.html
#
# Histograma da Expressões Genicas de g0

# %%
import seaborn as sns
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(15, 5)) # Tamanho do gráfico

ax1 = fig.add_subplot(1, 2, 1)  # Adicionando a posição do primeir gráfico, 1 linha, 1 coluna, 1ª Posição
ax2 = fig.add_subplot(1, 2, 2)  # Adicionando a posição do segundo gráfico, 1 linha, 1 coluna, 2ª Posição

ax1.set_xlabel('g0', fontsize=14) # Adicionando a legenda dos eixo x
ax1.set_title('Histograma - Expressão Gênica - Sem kde', fontsize=12)  # Adicionando o título do pimeiro gráfico
sns.histplot(data = dados['g0'], ax = ax1, bins=30, color='teal') 

ax2.set_xlabel('g0', fontsize=14)  # Adicionando a legenda dos eixo x
ax2.set_title('Histograma - Expressão Gênica - Com kde', fontsize=12)  # Adicionando o título do segundo gráfico
sns.histplot(data = dados['g0'], ax = ax2, bins=30, kde = True, color='teal')


plt.show()

# %% [markdown]
# Histogramas dos valores médios, máximos e míninos de todos os genes (g_0 ao g_771)

# %%
media_genes = dados.loc[:, 'g0':'g771'].describe().T['mean']  # Calculando o valor médio da expressão gênica de cada gene
media_genes
# Out:
# g0      0.248366
# g1     -0.095684
# g2      0.152253
# g3      0.081971
# g4      0.057347
#           ...
# g767   -0.076251
# g768    0.134162
# g769   -0.128018
# g770   -0.219210
# g771    0.101524
# Name: mean, Length: 772, dtype: float64

# %%
minimo_genes = dados.loc[:, 'g0':'g771'].describe().T['min']  # Calculando o valor mínino da expressão gênica para cada gene
minimo_genes
# Out:
# g0      -5.513
# g1      -5.737
# g2      -9.104
# g3      -5.998
# g4      -6.369
#          ...
# g767   -10.000
# g768    -4.269
# g769   -10.000
# g770   -10.000
# g771   -10.000
# Name: min, Length: 772, dtype: float64

# %%
maximo_genes = dados.loc[:, 'g0':'g771'].describe().T['max']  # Calculando o valor máximo da expressão gênica para cada gene
maximo_genes
# Out:
# g0      10.000
# g1       5.039
# g2       8.257
# g3      10.000
# g4      10.000
#          ...
# g767     6.317
# g768    10.000
# g769     5.911
# g770    10.000
# g771    10.000
# Name: max, Length: 772, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(20, 5)) # Tamanho do gráfico

ax1 = fig.add_subplot(1, 3, 1)  # Adicionando a posição do primeir gráfico, 1 linha, 1 coluna, 1ª Posição
ax2 = fig.add_subplot(1, 3, 2)  # Adicionando a posição do segundo gráfico, 1 linha, 1 coluna, 2ª Posição
ax3 = fig.add_subplot(1, 3, 3)  # Adicionando a posição do segundo gráfico, 1 linha, 1 coluna, 3ª Posição

ax1.set_xlabel('Valores Médios', fontsize=14) # Adicionando a legenda dos eixo x
ax1.set_title('Histograma - Valores Médios das Expressões Gênicas', fontsize=14)  # Adicionando o título do pimeiro gráfico
sns.histplot(media_genes, ax = ax1, bins=50, color='teal') 

ax2.set_xlabel('Valores Mínimos', fontsize=14) # Adicionando a legenda dos eixo x
ax2.set_title('Histograma - Valores Mínimos das Expressões Gênicas', fontsize=14)  # Adicionando o título do pimeiro gráfico
sns.histplot(minimo_genes, ax = ax2, bins=50, color='teal') 

ax3.set_xlabel('Valores Máximos', fontsize=14) # Adicionando a legenda dos eixo x
ax3.set_title('Histograma - Valores Máximos Expressões Gênicas', fontsize=14)  # Adicionando o título do pimeiro gráfico
sns.histplot(maximo_genes, ax = ax3, bins=50, color='teal') 

plt.show()

# %% [markdown]
# Podemos concluir que:
#
# A a maior parte dos genes possui valor médio de expressão gênica entre -0.1 e 0.1
# A maior parte dos genes tem seu valor mínimo de expressão gênica igual a -10
# A maior parte dos genes tem seu valor máximo de expressão gênica igual a 10

# %% [markdown]
# ### Desafios 04: Estudar sobre as estatísticas retornadas no .discribe()
# count, mean, min, max...

# %% [markdown]
# **Máximo e Mínimo**
# - A mínima e a máxima são os valores nos “extremos” de um conjunto de dados ordenados: ou seja, o menor e o maior valor. Ambos são utilizados cotidianamente e facilmente compreensíveis para quase toda população, pense – por exemplo – em seu uso diário na previsão do tempo."
#
# **Média**
# - Média (M), mais precisamente chamada de média aritmética simples, é o resultado da soma de todas as informações de um conjunto de dados dividida pelo número de informações que foram somadas."
#
# **Mediana**
# - Se o conjunto de informações for numérico e estiver organizado em ordem crescente ou decrescente, a sua mediana será o número que ocupa a posição central da lista."
#
# **Desvio Padrão**
# - Em probabilidade, o desvio padrão ou desvio padrão populacional é uma medida de dispersão em torno da média populacional de uma variável aleatória. O termo possui também uma acepção específica no campo da estatística, na qual também é chamado de desvio padrão amostral e indica uma medida de dispersão dos dados em torno de média amostral. Um baixo desvio padrão indica que os pontos dos dados tendem a estar próximos da média ou do valor esperado. Um alto desvio padrão indica que os pontos dos dados estão espalhados por uma ampla gama de valores. O desvio padrão populacional ou amostral é a raiz quadrada da variância populacional ou amostral correspondente, de modo a ser uma medida de dispersão que seja um número não negativo e que use a mesma unidade de medida dos dados fornecidos."
#
# **Variação Interquartil (Q3-Q1)**
# - Tanto o desvio padrão quanto a variância dependem da média, portanto, são afetados por valores extremos. Mas há uma medida de dispersão baseada na mediana, que consegue contornar a presença destes outliers: a variação interquartil, abreviada para IQR em inglês. Para descobrir a variação interquartil, primeiramente, dividimos os dados em duas metades, como na mediana, para em seguida refazer esta operação com cada uma das duas metades. Obtemos então quatro partes iguais – ou quartis. Agora, você subtrai a mediana da metade superior (terceiro quartil ou Q3) com a mediana da metade inferior (primeiro quartil ou Q1). A vantagem deste método é que ele, por definição, já isola os outliers, seja inferiores ou superiores."
#
# **OUTLIERS**
# - São valores atípicos entre os dados analisados. Isto é avaliado a partir do quanto um determinado valor difere dos demais em um conjunto de dados. Eles podem trazer tanto uma má notícia, como erros na coleta ou limpeza dos dados, como também boas novas, como os casos que fogem da regra e podem ganhar destaque na sua análise. Por um lado, os outliers podem revelar um erro a ser corrigido ou pelo menos considerado, antes de avançarmos com a análise. Por isso, é importante começar as análises identificando-os, pois eles podem ser indícios de erros de medição ou falhas na limpeza de dados."
# Referências: https://escoladedados.org/tutoriais/analise-com-estatistica-descritiva-para-leigos/ https://pt.wikipedia.org/wiki/Desvio_padr%C3%A3o https://operdata.com.br/blog/desvio-padrao-e-erro-padrao/ https://brasilescola.uol.com.br/matematica/moda-media-mediana.htm

# %% [markdown]
# ### Desafios 05: Refletir sobre a manipulação do tamanho das visualizações.

# %% [markdown]
# Buscando realizar um reflexão sobre o tamanho das visualizações, farei uma comparação plotando os mesmos gráficos, porém utilizando, priemiramente, um tamanho menor na horizontal e no segundo gráfico colocarei um tamanho maior pra este mesmo eixo.

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x = 'g0', y = 'tratamento', data = dados)

plt.figure(figsize=(18,5))
sns.boxplot(x = 'g0', y = 'tratamento',  data = dados)

# %% [markdown]
# Realizando a análise com tamanho maior na horizontal podemos verificar melhor a distribuição dos outliers e também conseguimos uma melhor visualização da diferença entre as medianas.

# %% [markdown]
# ### Desafios 06: Fazer outras análises com o boxplot e até com o histograma

# %% [markdown]
# Verificando as expressões genéticas do g_0 com relaçao as doses

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x = 'g0', y = 'dose', data = dados)

plt.figure(figsize=(20, 5))
sns.boxplot(x = 'g0', y = 'dose', data = dados)

plt.show()

# %% [markdown]
# Ampliando o eixo x, verificamos uma configuração bem parecida das expressões gênicas, percebe-se uma diferença mais aparente nos pontos de máximo e mínimo.
#
# Dosagem e expressões genética para todas as colunas de genes
# Abaixo realizei um filtro, primeiro, com a dosagem 1 (D1) para todos os genes a fim de verificar os valores médios, máximos e mínimos das expressões genéticas. Repeti toda a operação para dosagem 2 (D2)
#
# O objetivo era verificar o comportamento da expressão gênica com diferentes dosagens.

# %%
media_d1 = dados.query('dose == "D1"').loc[:, 'g0': 'g771'].describe().T['mean']

# %%
max_d1 = dados.query('dose == "D1"').loc[:, 'g0': 'g771'].describe().T['max']

# %%
min_d1 = dados.query('dose == "D1"').loc[:, 'g0': 'g771'].describe().T['min']

# %%
media_d2 = dados.query('dose == "D2"').loc[:, 'g0': 'g771'].describe().T['mean']

# %%
min_d2 = dados.query('dose == "D2"').loc[:, 'g0': 'g771'].describe().T['min']

# %%
max_d2 = dados.query('dose == "D2"').loc[:, 'g0': 'g771'].describe().T['max']

# %%
import seaborn as sns
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(20,13)) # Tamanho do gráfico

ax1 = fig.add_subplot(2, 3, 1)  # Adicionando a posição do primeir gráfico, 1 linha, 1 coluna, 1ª Posição
ax2 = fig.add_subplot(2, 3, 2)  # Adicionando a posição do segundo gráfico, 1 linha, 1 coluna, 2ª Posição
ax3 = fig.add_subplot(2, 3, 3)  # Adicionando a posição do segundo gráfico, 1 linha, 1 coluna, 3ª Posição
ax4 = fig.add_subplot(2, 3, 4)  # Adicionando a posição do primeir gráfico, 1 linha, 1 coluna, 4ª Posição
ax5 = fig.add_subplot(2, 3, 5)  # Adicionando a posição do segundo gráfico, 1 linha, 1 coluna, 5ª Posição
ax6 = fig.add_subplot(2, 3, 6)  # Adicionando a posição do segundo gráfico, 1 linha, 1 coluna, 6ª Posição

ax1.set_xlabel('Valores Médios', fontsize=14) # Adicionando a legenda dos eixo x
ax1.set_title('Valores Médios das Expressões Gênicas para D1', fontsize=14)  # Adicionando o título do pimeiro gráfico
sns.histplot(media_d1, ax = ax1, bins=30, kde = True, color='teal') 

ax2.set_xlabel('Valores Mínimos', fontsize=14) # Adicionando a legenda dos eixo x
ax2.set_title('Valores Mínimos das Expressões Gênicas para D1 ', fontsize=14)  # Adicionando o título do pimeiro gráfico
sns.histplot(min_d1, ax = ax2, bins=50, color='teal') 

ax3.set_xlabel('Valores Máximos', fontsize=14) # Adicionando a legenda dos eixo x
ax3.set_title('Valores Máximos Expressões Gênicas para D1', fontsize=14)  # Adicionando o título do pimeiro gráfico
sns.histplot(max_d1, ax = ax3, bins=50, color='teal') 

ax4.set_xlabel('Valores Médios', fontsize=14) # Adicionando a legenda dos eixo x
ax4.set_title('Valores Médios das Expressões Gênicas para D2', fontsize=14)  # Adicionando o título do pimeiro gráfico
sns.histplot(media_d2, ax = ax4, bins=30, kde = True, color='teal') 

ax5.set_xlabel('Valores Mínimos', fontsize=14) # Adicionando a legenda dos eixo x
ax5.set_title('Valores Mínimos das Expressões Gênicas para D2 ', fontsize=14)  # Adicionando o título do pimeiro gráfico
sns.histplot(min_d2, ax = ax5, bins=50, color='teal') 

ax6.set_xlabel('Valores Máximos', fontsize=14) # Adicionando a legenda dos eixo x
ax6.set_title('Valores Máximos Expressões Gênicas para D2', fontsize=14)  # Adicionando o título do pimeiro gráfico
sns.histplot(max_d2, ax = ax6, bins=50, color='teal') 


plt.show()

# %% [markdown]
# No que se refere a comparação das médias verificamos que para D1 pontos de concetraçao das médias entre 0 e -0.1, para a dose D2 temos uma concentração próximo ao 0. Já os valores de máximo e mínimo vemos comportamentos bem parecidos com concentração em 10 e -10, respectivamente.

# %% [markdown]
# ### Desafios 07: Resumo do que você aprendeu

# %% [markdown]
# Hoje podemos aprender um pouco mais sobre distibuição dos dados utilizando os gráficos de de Boxplot e Histograma para analisar os dados.

# %% [markdown]
# # Aula 3

# %% [markdown]
# Seja bem-vindo e bem-vinda à terceira aula da Imersão Dados 3ª Edição!
#
# Nesta aula aprendemos como cruzar informações dos dados, analisando as relações de diversas colunas entre sí, iniciaremos relacionando os dados de experimentos e posteriormente os tipos genéticos. Em seguida utilizamos o gráfico de dispersão para investigar a relação entre os genes. Por fim, aprendemos o que é correlação discutindo também sobre causalidade, nosso objetivo é através da correlação levantar possíveis hipóteses relacionadas aos estímulos biológicos provocados pelos experimentos nas amostras celulares, por fim aprendemos como visualizar a correlação em um mapa de calor.

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# Conforme nossa busca na [documentação do Pandas](https://pandas.pydata.org), encontramos uma maneira para construir uma tabela de frequências, a função ```crosstab```. Esta função recebe como argumentos os dados que gostaríamos de correlacionar de uma maneira bem simples: ```crosstab(dataframe['coluna1'], dataframe['coluna2'])``` e então, como retorno, temos uma matriz que relaciona essas variáveis a partir da frequência.
#
# Podemos ver que as categorias da variável ```dose``` transformaram-se em linhas e as categorias da variável ```tempo``` são colunas.

# %%
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %% [markdown]
# Entretanto, na matriz acima não estamos considerando o tratamento usado, apesar desta variável ser de suma importância, visto que, decide se há ou não presença de um composto no evento.
# Por isso, vamos construir uma nova tabela com o ```crosstab``` considerando essa nova variável.
#
# Para isso, usaremos a mesma sintaxe anterior, adicionando ```dados['tratamento']```ao final e, adicionalmente, deixamos as duas primeiras colunas declaradas entre colchetes, pois assim garantimos que suas informações estarão distribuídas nas linhas, ou seja, o código final para este comando será: ```crosstab(dataframe[['coluna1'], dataframe['coluna2']], dataframe['coluna3'])```.
#
# O resultado será uma tabela de frequências multi-index (mais de um índice) sendo que o index da esquerda se refere aos dados da variável ```dose``` e o index da direita são as informações de ```tempo```, respeitando a ordem na qual declaramos as respectivas variáveis.

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %% [markdown]
# Apesar de já termos construído uma tabela bem interessante através da frequência de algumas variáveis, podemos explorar a proporção destes dados entre si.
#
# Para fazer isso vamos, novamente, copiar o nosso comando acrescentando um novo parâmetro ao final, o ```normalize```. Então o código ficará: ```crosstab([dados['dose'], dados['tempo']],  dados['tratamento'], normalize='index')```. Esse parâmetro normaliza a nossa tabela e escolhemos que ela faça isso a partir do índice, ou seja, ela fará a comparação entre as categorias, isto é, a soma de cada linha será igual a 1.
# Fazer este tipo de análise possibilita que façamos algumas suposições acerca do balanceamento entre as categorias e, analisando a nossa matriz, podemos concluir que há proporcionalidade na nossa base de dados.

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %% [markdown]
# Podemos também agregar à nossa matriz uma métrica estatística associada a uma coluna.
# Para que isso seja cumprido, adicionamos mais dois parâmetros à nossa função ```crosstab```: o primeiro é o ```values = dataframe['variavel']``` e o segundo é o ```aggfunc``` que recebe como parâmetro alguma métrica estatística, como a média. Logo, ```aggfunc = 'mean'```. Isso quer dizer que queremos comparar entre as diferentes categorias (```com_controle``` e ```com_droga```) a média de valores associados a variável ```g-0```.
#
# Aqui, podemos perceber algumas diferenças entre essas médias e podemos traçar algumas hipóteses a serem verificadas. Lembrando que a média de uma variável, é uma conta feita a partir dos valores que aquela amostra apresenta e não é o valor que ela assume, de fato. Por isso, não podemos concluir nada somente olhando a média, mas entender seu comportamento nos dá indícios por quais caminhos podemos seguir.

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %% [markdown]
# Para variáveis contínuas, fazer tabelas de frequências não é a melhor estratégia para analisá-las.
# Mas, construir um novo tipo de gráfico pode ser muito interessante para o nosso processo.
#
# Então, para fins de visualização, o primeiro passo é filtrar a nossa base de dados com as colunas que queremos investigar.
# No nosso caso, vamos analisar a relação entre as colunas ```g-0``` e ```g-3``` e, por isso, definimos uma lista de arrays com os nomes dessas colunas (```dataframe[['coluna1', 'coluna2']]```) e, como retorno, teremos nosso conjunto somente com as variáveis alvo.

# %%
dados[['g0', 'g3']]
# Out:
#            g0      g3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %% [markdown]
# O ```scatterplot``` é um tipo de gráfico pré programado da biblioteca Seaborn e recebe como parâmetros a variável que vai ser usada no eixo x, a variável do eixo y e, por fim, o conjunto de dados.
#
# O código ficará:
#
# ```sns.scatterplot(x = 'variavel para o eixo x', y = 'variavel para o eixo y', data = base de dados)```
#
# E, como queremos investigar as variáveis ```g-0``` e ```g-3```, atribuímos cada uma delas a um eixo.
#
# O gráfico de dispersão utiliza os dados como uma coleção de pontos cartesianos e ele é usado para apurar se há relação de causa e efeito entre duas variáveis quantitativas.
#
# No nosso caso, cada linha será um par ordenado de acordo com o que declaramos no código, ou seja, o valor de ```g-0``` será a cordenada x e o valor de ```g-3``` será a coordenada y.
#
# Por exemplo: para a linha 0 da base de dados teremos (1,0620 , -0,6208)
#
# Mas, por outro lado, a partir do gráfico de dispersão, não podemos dizer que uma variável afeta a outra, podemos apenas definir se há relação entre elas e qual a intensidade disso.

# %%
sns.scatterplot(x='g0', y='g3', data=dados)

# %% [markdown]
# Observando o gráfico que construímos acima, não parecemos encontrar nenhum padrão tão definido. Então, vamos confrontar mais duas colunas para verificar se encontramos algum padrão melhor definido.
#
# Aqui, vamos usar a variável ```g-0``` para o eixo x e a variável ```g-8``` para o eixo y para construir o nosso novo gráfico.
#
# Como retorno, recebemos um gráfico de dispersão onde a nuvem de pontos cartesianos parece desenhar melhor um padrão: conforme o ```g-0``` aumenta, o valor de ```g-8``` diminui. Aparentemente, a relação entre essas duas variáveis desenha uma curva com inclinação negativa.

# %%
sns.scatterplot(x='g0', y='g8', data=dados)

# %% [markdown]
# E, como parte do nosso trabalho é levantar hipóteses e confirmá-las (ou não), precisamos verificar se a nossa suspeita de que a relação entre as variáveis ```g-0``` e ```g-8```desenha uma curva com inclinação negativa.
#
# Para isso, vamos utilizar uma outra função do Seaborn, a ```lmplot```. A ```lmplot``` vai desenhar no nosso gráfico de dispersão uma linha de tendência e, assim, poderemos confirmar o padrão daquele conjunto de dados.
#
# Os parâmetros a serem recebidos, são muito parecidos com aqueles usados no ```scatterplot```. Então teremos
#
# ```sns.lmplot(data=base de dados, x='variavel para o eixo x', y='variavel para o eixo y', line_kws={'color': 'cor da linha de tendencia'})```
#
# Utilizamos o parâmetro ```line_kws = {'color': 'red'}``` para criar um bom contraste entre os pontos do gráfico de dispersão e a linha de tendência.
#
# Observando o nosso gráfico, podemos concluir a nossa hipótese inicial, mas ele ainda não é suficiente para finalizarmos a nossa análise.

# %%
sns.lmplot(x='g0', y='g8', data=dados, line_kws={'color':'red'})

# %% [markdown]
# Para uma análise mais real e completa, é interessante que separemos ainda mais o nosso conjunto de dados. Isso porque, na imagem acima, apesar de termos uma linha de tendência para a relação entre os dados ```g-0``` e ```g-8```, não há filtros para a dosagem, o tratamento e o tempo. E, pesando em drug discorevy, é extremamente importante que façamos a separação desses conjuntos.
#
# Então, vamos acrescentar mais alguns parâmetros para executar a separação. Acrescentamos o parâmetro ```col = tramento``` para que sejam plotados gráficos de acordo com as categorias da variável em questão nas colunas (```com_droga``` e ```com_controle```) e também incluímos o parâmetro ```row = 'tempo'``` para que mais uma subdivisão seja feita e, as linhas apresentem novos gráficos com as diferentes categorias (```24```,```48``` e ```72```).
#
# Assim, podemos perceber as nuances de cada gráfico e o comportamento de determinado subconjunto.

# %%
sns.lmplot(x='g0', y='g8', data=dados, line_kws={'color':'red'}, col='tratamento')

# %%
sns.lmplot(x='g0', y='g8', data=dados, line_kws={'color':'red'}, col='tratamento', row='tempo')

# %% [markdown]
# Outra medida para analisar como as variáveis estão associadas é a correlação.
#
# Para isso, vamos usar uma função já conhecida do Pandas, o ```loc``` e, vamos agregar o ```.corr```. O ```loc``` serve para definirmos o intervalo em que a correlação vai ser calculada. Aqui, estamos calculando a correlação entre todos os genes.
#
# Como retorno, temos uma tabela bem grande que correlaciona a variável e apresenta valores entre 1 e -1.
# Por exemplo, o primeiro valor numérico apresentado na primeira linha é o resultado da correlação entre a variável que está nesta linha e nesta coluna, no nosso caso, o ```g-0``` em ambas as extremidades. No primeiro valor numérico apresentado na segunda linha, temos a correlação entre ```g-1``` e ```g-0``` e assim por diante.
#
# Mas, como interpretar esses valores? Bom, temos a seguinte divisão:
#
#     - Valores muito próximos de 1 ou -1: variáveis altamente correlacionadas
#     - Valores muito próximos de 0: variáveis pouco ou não correlacionadas
#
# E, o que diferencia se essa correlação será proporcional ou inversamente proporcional, será o sinal. Quer dizer:
#
#     - Valores muito próximos de 1: variáveis proporcionalmente correlacionadas
#     - Valores muito próximos de -1: variáveis correlacionadas inversamente proporcionais
#
# Agora que já sabemos como analisar essa tabela, podemos voltar para o nosso gráfico de dispersão construído com ```g-0``` e ```g-8`` e perceber que a nossa tabela confirma que ambas as variáveis estão correlacionadas e são inversamente proporcionais, visto que o valor apresentado na tabela é de -0,604212.

# %%
dados.loc[:,'g0':'g771'].corr()
# Out:
#             g0        g1        g2  ...      g769      g770      g771
# g0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...        ...       ...       ...  ...       ...       ...       ...
# g767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %% [markdown]
# Analisar essa grande tabela é um desafio bem grande. Então, como auxílio visual costumamos plotar um mapa de calor para que possamos identificar com maior facilidade a correlação entre as variáveis.
#
# E, como esse código já está construído na própria documentação do Seaborn, vamos copiar o [código](https://seaborn.pydata.org/examples/many_pairwise_correlations.html) de lá, fazendo apenas algumas pequenas alterações.
#
# Então, de ```corr = d.corr()``` mudamos para ```corr = dados.loc[:,'g-0':'g-50'].corr()``` pois ajustamos o ```d``` para a nossa base de dados (```dados```) e decidimos incluir um ```loc``` para fazer o mapa de calor apenas do ```g-0``` ao ```g-50```.
# Também retiramos o parâmetro ```vmax=.3``` da última parte do código pois este era um limitador da correlação que não nos interessa no momento.
#
# Adicionalmente, também fizemos a importação da biblioteca Numpy que é usada para gerar este mapa de calor (```import numpy as np```).

# %%
import numpy as np

# Compute the correlation matrix
corr = dados.loc[:,'g0':'g50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# Agora, vamos repetir o processo de construção do mapa de calor para a a viabilidade celular (```c```).
#
# Definimos uma nova variável ```corr_celular``` e ajustamos os parâmetros de acordo com os nossos ```cs```.
#
# Observando o gráfico de saída, podemos perceber uma grande diferença entre os dois mapas de calor que construímos. A escala deste novo gráfico é bem diferente da escala anterior, temos valores apenas entre 0,65 e 0,90, correlações altamente proporcionais.

# %% [markdown]
# site: spurios correlations

# %%
# Compute the correlation matrix
corr_celular = dados.loc[:,'c0':'c50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ## Desafios

# %% [markdown]
# ### Desafios 01: Criar tabelas de frequência com o pandas .groupby

# %% [markdown]
# O método pandas.groupby() é uma outra forma de agrupar dados da base de dados e realizar a contagem e/ou aplicar métricas estatísticas. Seguindo o exemplo os exemplos da aula, irei construir as mesmas tabelas de frequência já mencionadas.
#
# O método funciona da seguinte forma: primeiro irei dizer ao método como irei agrupar meu dados. Depois, irei selecionar a variável que eu desejo visualizar e aplicar a métrica estátistica que o agrupamento deverá demonstrar.
#
# (https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html)

# %%
#Construindo tabela 1 (frequência dose x tempo)
tabela1 = dados.groupby(by=['dose'])['tempo'].value_counts() #uso value_counts já que quero a quantidade (frequência) de cada tempo pra cada dose
tabela1.unstack()
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
#Construindo tabela 2 (frequência dose e tempo x tratamento)
tabela2 = dados.groupby(by=['dose','tempo'])['tratamento'].value_counts()
tabela2.unstack()
#para cosntruir a tabela 3 (com a frequência relativa, devo simplesmente utilizar normalize=True dentro do método value_counts)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
#Tabela 3 (média do gene g-0 agrupando por dose, tempo e tratamento)
tabela4 = dados.groupby(by=['dose','tempo','tratamento'])['g0'].mean()
tabela4.unstack()
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %% [markdown]
# ### Desafios 02: Normalizar o crosstabl pela coluna.

# %% [markdown]
# Aqui, devo simplesmente normalizar os dados utilizando as colunas da crosstab, ou seja, passando o argumento 'columns'

# %%
pd.crosstab([dados['dose'], dados['tempo']],  dados['tratamento'], normalize='columns')
#o código abaixo demonstra que a soma dos valores da coluna com_controle é igual a 1 (o esperado)
#pd.crosstab([dados['dose'], dados['tempo']],  dados['tratamento'], normalize='columns')['com_controle'].sum()

# %% [markdown]
# ### Desafios 03: Explorar outros agregadores.

# %% [markdown]
# Como mencionado pelo Guilherme durante a aula, depois que fazemos o agrupamento, podemos extrair diferentes valores estatisticos. Assim como o método .describe(), podemos retornar os valores de mediana, mínimos, maximos, desvios padrões, etc.

# %%
medianas = dados.groupby(by=['dose','tempo','tratamento'])['g0'].median() #mostra a médiana
medianas.unstack()
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24          -0.2912    0.02700
#      48          -0.2145    0.01620
#      72          -0.3655    0.02615
# D2   24           0.0096   -0.02610
#      48          -0.0506   -0.02960
#      72           0.0528    0.00015

# %% [markdown]
# ### Desafios 04: Explorar o melt.

# %% [markdown]
# Pela própia descrição do método na documentação do Pandas, melt() é uma forma de mudar a apresentação da sua tabela, girando as colunas em linhas. Aqui, podemos escolher uma (ou mais) variável identificadora e as demais colunas servirão como variáveis medidas aonde seus valores pra respectivas variáveis indentificadoras serão demonstradas em values.
#
# https://pandas.pydata.org/docs/reference/api/pandas.melt.html

# %%
#nesse exemplo eu consigo vizualizar para cada tipo de dose, pra cada tempo e para cada tipo de tratamento qual o valor da expressão do gene g-0
pd.melt(dados,id_vars=['dose','tempo','tratamento'],value_vars=['g0'])
# Out:
#       dose  tempo    tratamento variable   value
# 0       D1     24     com_droga       g0  1.0620
# 1       D1     72     com_droga       g0  0.0743
# 2       D1     48     com_droga       g0  0.6280
# 3       D1     48     com_droga       g0 -0.5138
# 4       D2     72     com_droga       g0 -0.3254
# ...    ...    ...           ...      ...     ...
# 23809   D2     24     com_droga       g0  0.1394
# 23810   D2     24     com_droga       g0 -1.3260
# 23811   D2     48  com_controle       g0  0.3942
# 23812   D1     24     com_droga       g0  0.6660
# 23813   D1     72     com_droga       g0 -0.8598
#
# [23814 rows x 5 columns]

# %% [markdown]
# ### Desafios 05: Calcular e analisar a correlação de G(genicas) e C(tipos celulares). Refletir sobre os efeitos biológicos.

# %% [markdown]
# Para começar, seria interessante separar os dados pelo tipo de tratamento, já que queremos entender qual a influência das drogas utilizadas no ensaio realizado. Depois, iremos selecionar 50 genes e células para poder plotar a correlação.
#
# a explicação do código do plot do heatmap será feito na mesma célula do plot a correlação.

# %%
# Filtrando tratamento igual a com_droga separando os 50 primeiros genes e tipos celulares
genes = dados[dados['tratamento'] == 'com_droga'].loc[:,'g0':'g49']
celulas = dados[dados['tratamento'] == 'com_droga'].loc[:,'c0':'c49']

# Concatenando e criando um dataframe unico com esses valores
tabela = pd.concat([genes,celulas],axis=1) #axis = 1 diz que eu quero juntar os dataframes acima por coluna
tabela
# Out:
#            g0      g1      g2      g3  ...     c46     c47     c48     c49
# 0      1.0620  0.5577 -0.2479 -0.6208  ...  1.0340  1.3070 -1.0230  0.7709
# 1      0.0743  0.4087  0.2991  0.0604  ... -0.5658  0.6065  0.6259  0.4716
# 2      0.6280  0.5817  1.5540 -0.0764  ... -0.3181  0.1787  0.3354  0.1349
# 3     -0.5138 -0.2491 -0.2656  0.5288  ... -2.0030 -1.3390 -3.0160 -3.0040
# 4     -0.3254 -0.4009  0.9700  0.6919  ...  0.5903 -0.2353 -0.1285 -0.1740
# ...       ...     ...     ...     ...  ...     ...     ...     ...     ...
# 23808  0.1608 -1.0500  0.2551 -0.2239  ...  0.2558  0.3631 -0.0474 -0.6761
# 23809  0.1394 -0.0636 -0.1112 -0.5080  ...  0.5270 -0.6097  0.7577  0.0365
# 23810 -1.3260  0.3478 -0.3743  0.9905  ... -0.5548 -0.7309  0.2137 -0.1295
# 23812  0.6660  0.2324  0.4392  0.2044  ...  0.3351  0.5460 -0.7703 -0.1128
# 23813 -0.8598  1.0240 -0.1361  0.7952  ... -3.0640 -0.7138 -1.6730 -1.4890
#
# [21948 rows x 100 columns]

# %%
#criando tabela de correlação
corr = tabela.corr().round(2)
corr
# Out:
#        g0    g1    g2    g3    g4    g5  ...   c44   c45   c46   c47   c48   c49
# g0   1.00  0.07  0.18  0.02  0.41 -0.17  ... -0.66 -0.66 -0.61 -0.66 -0.60 -0.62
# g1   0.07  1.00 -0.05 -0.01  0.16 -0.14  ... -0.00 -0.00 -0.01  0.01  0.00  0.04
# g2   0.18 -0.05  1.00  0.04  0.03  0.01  ... -0.19 -0.18 -0.17 -0.18 -0.16 -0.17
# g3   0.02 -0.01  0.04  1.00 -0.02  0.05  ... -0.07 -0.08 -0.03 -0.07 -0.06 -0.04
# g4   0.41  0.16  0.03 -0.02  1.00 -0.06  ... -0.40 -0.40 -0.37 -0.41 -0.36 -0.36
# ..    ...   ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...   ...
# c45 -0.66 -0.00 -0.18 -0.08 -0.40  0.19  ...  0.88  1.00  0.82  0.87  0.83  0.82
# c46 -0.61 -0.01 -0.17 -0.03 -0.37  0.20  ...  0.82  0.82  1.00  0.82  0.82  0.82
# c47 -0.66  0.01 -0.18 -0.07 -0.41  0.20  ...  0.85  0.87  0.82  1.00  0.85  0.85
# c48 -0.60  0.00 -0.16 -0.06 -0.36  0.20  ...  0.81  0.83  0.82  0.85  1.00  0.86
# c49 -0.62  0.04 -0.17 -0.04 -0.36  0.20  ...  0.81  0.82  0.82  0.85  0.86  1.00
#
# ...

# %%
#como eu quero somente a corelação de cada gene com cada celula, eu posso filtrar minha matrix de corelação da seguinte forma
corr_filtrada = corr.loc[:'g49','c0':]
corr_filtrada.shape
#o formato da tabela de corelação filtrada mostra que aqui eu tenho os valores de correlação excluindo genes entre genes e celulas entre celulas
# Out:
# (50, 50)

# %%
# Generate a mask for the upper triangle
#mask = np.triu(np.ones_like(corr_filtrada, dtype=bool))
'''a variável mask é um triangulo superior (np.triu) de uma array das mesmas dimensões que nossa matrix de correlação
e seus valores são do tipo booleano e iguais a 1. Nessa caso, como eu já filtrei as correlações que quero, não preciso usar a mascara
para esconder o triangulo superior do heatmap'''

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))
'''criando minha área de plot'''

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)
'''criando uma paleta de cores divergentes entre duas cores HUSL (cor 230 e cor 20) retornando um mapa de cores
para ser usado no plot heatmap'''

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_filtrada, cmap=cmap, center=0, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# A nova matriz de correlação consegue demonstrar algumas coisas interessantes para os genes e células selecionados:
#
# 1) Existe genes com uma correlação bem positiva com a viabilidade celular (g-41, por exemplo). No caso da correlação positiva podemos dizer que uma alta expressão desse gene está relacionado de alguma forma com a alta viabilidade celular, já que a correlação diz que ambos os valores tendem a mudar na mesma direção.
#
# 2) Existem genes que possuem uma correlação bastante negativa com vários tipos de células (g-46, por exemplo). Isso quer dizer que seus valores mudam em direções opostos. Entretanto, somente pelo valor da correlação, não podemos dizer se o aumento da expressão do gene indica redução da viabilidade celular ou vice-versa. Porém, isso pode ser visto pelo lmplot (demonstrado na linha de código abaixo).
#
# 3) Ambos os casos acima nós ajudam a resaltar genes que podem ser de interesse ter um estudo mais aprofundado.
#
# 2) muitos genes demonstram praticamente nenhuma correlação com as viabilidade celular. Isso pode demonstrar que esse genes não estão envolvidos diretamente em via metabólicas que irão resultar na sobrevivem ou morte da célula em questão sobre o efeito dos compostos testados, e podem não ser de interesse continuar analisando-os nas próximas etapas do estudos.

# %%
'''Podemos ver que o aumento da expressão do gene g-46 está relacionado de alguma forma com a
redução da viabilidade celular da célula c-0'''
sns.lmplot(data=dados, x='g46', y='c0', line_kws={'color': 'red'}, col='tratamento',row='tempo')

# %% [markdown]
# ### Desafios 06: Estudar o código que plota a matriz de correlação (heatmap)

# %% [markdown]
# Heatmap (ou mapa de calor) é um relatório gerado por ferramentas automáticas que utiliza as cores como referência para facilitar o entendimento das informações. No marketing digital, normalmente rastreia o caminho percorrido pelo mouse do usuário para compreender seu comportamento em uma página de conversão.
#
# link: https://seaborn.pydata.org/generated/seaborn.heatmap.html
#
#
# `seaborn.heatmap
# seaborn.heatmap( dados , * , vmin = None , vmax = None , cmap = None , center = None , robust = False , annot = None , fmt = '.2g' , annot_kws = None , linewidths = 0 , linecolor = 'white' , cbar = Verdadeiro , cbar_kws = Nenhum ,cbar_ax = None , square = False , xticklabels = 'auto' , yticklabels = 'auto' , mask = None , ax = None , ** kwargs )
# Plote dados retangulares como uma matriz codificada por cores.`
#
# Esta é uma função no nível dos eixos e atrairá o mapa de calor para os eixos ativos no momento se nenhum for fornecido para o axargumento. Parte deste espaço dos eixos será tomado e usado para plotar um mapa de cores, a menos que cbar seja False ou um eixo separado seja fornecido `cbar_ax`.

# %% [markdown]
# ### Desafios 07: Resumo do que você aprendeu

# %% [markdown]
# Aprendemos como tirar insights que vão ajudar e guiar as etapas seguintes do estudo sendo realizado. Começamos a enxergar como que certos compostos interferem na expressão de um gene e como isso está relacionado com a viabilidade celular de diferentes tipos de células.
#
# Particulamente, eu nunca havia utilizado o método crosstab e achei excelente a forma limpa e de fácil leitura de suas resposta quando comparado com o método groupby, o qual eu já possuia contato.

# %% [markdown]
# # Aula 4

# %% [markdown]
# Seja bem-vindo e bem-vinda à quarta aula da Imersão Dados 3ª Edição!
#
# Antes de falar sobre a Aula de hoje 2 recados importantes:
#
# Na live de quarta falamos sobre o projeto final, que você precisa submeter até domingo para concorrer a uma das 10 bolsas de estudo para o Bootcamp de DataScience aplicado da Alura. Todas as informações sobre o projeto final você encontra neste repositório.
#
# Agora no repositório do nosso projeto criamos a vitrine vai lá conferir os projetos incríveis que vocês estão desenvolvendo. E para ter seu projeto nesta vitrine, a única coisa que precisa é no repositório do seu projeto adicionar os tópicos alura e imersão dados. Para fazer isso é só clicar na engrenagem de configurações na parte superior direita do seu repositório ao lado de About.
#
# Até o momento trabalhamos com a base de dados experimentais e nesta aula, vamos analisar a base de dados resultados, combinando as duas bases com a função merge do pandas. Em seguida, vamos analisar a relação entre algumas informações da base de dados experimentais e resultados utilizando o boxplot. Por fim, entenderemos o que é o mecanismo de ação (MoA) de uma droga.
#
# Agora sim, vamos a aula!
#
# Nesta aula utilizaremos o arquivo de resultados para combinar com o arquivo de experimentos utilizando a função merge do pandas, facilitando a visualização do boxplot dos compostos.

# %%
dados_resultado = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultado.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %% [markdown]
# Numa analise inicial da nossa base de dados, temos que as colunas representam o mecanismo de ação das drogas, as quais podem ser ativadas ou não no alvo (enzima, proteina...). Observamos ainda que todos os valores parecem ser "zeros".
#
# Vamos observar se isso se confirma:

# %%
dados_resultado['acat_inhibitor'].unique()
# Out:
# array([0, 1])

# %%
dados_resultado['acetylcholine_receptor_agonist'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# Observamos apenas duas colunas, e temos que os valores são apenas 0 ou 1. Isso ocorre para todas as demais.
#
# Isso ocorre porque cada linha desta base de dados é o resultado da nossa outra base dados. Quando um determinado mecanismo de ação é ativado ele é indicado como 1. Quando esse mecanismo de ação não é ativado ele é detectado como 0.

# %%
dados_resultado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 209 entries, id to ativo_moa
# dtypes: bool(1), int64(207), object(1)
# memory usage: 37.8+ MB

# %%
# MOA -> mecanismo de ativação - quantidade de vezes que apareceu
# Primeira forma
contagem_moa = dados_resultado.select_dtypes('int64').sum()
contagem_moa
# Out:
# 5-alpha_reductase_inhibitor               17
# 11-beta-hsd1_inhibitor                    18
# acat_inhibitor                            24
# acetylcholine_receptor_agonist           190
# acetylcholine_receptor_antagonist        301
#                                         ...
# ubiquitin_specific_protease_inhibitor      6
# vegfr_inhibitor                          170
# vitamin_b                                 26
# vitamin_d_receptor_agonist                39
# wnt_inhibitor                             30
# Length: 206, dtype: int64

# %% [markdown]
# Observamos que todas as colunas são numéricas, exceto a 'id'.
# Vamos tentar descobrir qual é o mecanismo de ação mais utilizado?

# %%
#ordenando resultado
contagem_moa = dados_resultado.select_dtypes('int64').sum().sort_values(ascending = False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
# Informações da base de dados
dados_resultado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 207 entries, id to wnt_inhibitor
# dtypes: int64(206), object(1)
# memory usage: 37.6+ MB

# %%
# Segunda forma
contagem_moa = dados_resultado.drop('id', axis = 1).sum().sort_values(ascending = False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dados_resultado.drop('id', axis = 1).sum(axis = 1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultado['n_moa'] = dados_resultado.drop('id', axis = 1).sum(axis = 1)

# %%
dados_resultado['ativo_moa'] = (dados_resultado['n_moa'] != 0)
dados_resultado.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
dados_combinado = pd.merge(dados, dados_resultado[['id', 'n_moa', 'ativo_moa']],on = 'id')
dados_combinado.head()
# Out:
#              id tratamento  tempo dose  ...     c98     c99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
dados_combinado.query('tratamento == "com_controle"')
# Out:
#                  id    tratamento  tempo dose  ...     c98     c99  n_moa  ativo_moa
# 25     id_0054388ec  com_controle     48   D1  ...  0.8976  1.0050      0      False
# 38     id_0079af0fb  com_controle     24   D1  ...  0.6498 -1.4820      0      False
# 40     id_007bfbb91  com_controle     24   D2  ...  0.8543  0.9180      0      False
# 47     id_008a986b7  com_controle     48   D2  ... -0.9245 -0.9367      0      False
# 63     id_009d8340f  com_controle     24   D2  ... -0.4326  0.9364      0      False
# ...             ...           ...    ...  ...  ...     ...     ...    ...        ...
# 23729  id_ff1f9e5fc  com_controle     24   D1  ... -0.2422  0.0457      0      False
# 23747  id_ff469c482  com_controle     72   D1  ... -0.0742 -0.6777      0      False
# 23768  id_ff89331ca  com_controle     72   D2  ... -0.1748 -0.3626      0      False
# 23793  id_ffd26f361  com_controle     48   D2  ... -0.5272  0.7082      0      False
# ...

# %%
dados_combinado.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinado.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
composto_principal = dados_combinado['composto'].value_counts().index[:11]
# composto_principal
plt.figure(figsize=(12, 8))
sns.boxplot(data = dados_combinado.query('composto in @composto_principal'), y = 'g0', x = 'composto', hue = 'ativo_moa')

# %%
composto_principal = dados_combinado['composto'].value_counts().index[:5]
# composto_principal
plt.figure(figsize=(12, 8))
sns.boxplot(data = dados_combinado.query('composto in @composto_principal'), y = 'g0', x = 'composto', hue = 'ativo_moa')

# %% [markdown]
# ## Desafios

# %% [markdown]
# ### Desafio 01: Encontrar o TOP 10 das ações da MOA (inibidor, agonista...)

# %%
# Ja foi feito o split em desafios anteriores


# Separamos as ações em cada um dos mecânismos de ação.
# separacao_por_moa = [nome.split('_')[-1] for nome in contagem_moa.index]

# %%
#Criamos um Dataframe com as ação do MOA e os totais de cada uma delas por MOA
dados_resultados_moa = pd.DataFrame(data={'ação':separacao_por_moa, 
                                                       'totais':contagem_moa.values})
dados_resultados_moa
# Out:
#            ação  totais
# 0     inhibitor     832
# 1     inhibitor     726
# 2     inhibitor     435
# 3    antagonist     424
# 4    antagonist     404
# ..          ...     ...
# 201   inhibitor       6
# 202   inhibitor       6
# 203    diuretic       6
# 204   inhibitor       1
# 205  antagonist       1
#
# [206 rows x 2 columns]

# %%
# Agrupamos as ações nos 10 resultados mais relevantes
dados_resultados_moa_Top_10 = dados_resultados_moa.groupby('ação').sum().sort_values(by = 'totais', ascending=False)[:10]
dados_resultados_moa_Top_10
# Out:
#                    totais
# ação
# inhibitor            9693
# antagonist           3449
# agonist              2330
# blocker               323
# agent                 150
# activator             115
# local                  80
# antioxidant            73
# anti-inflammatory      73
# immunosuppressant      73

# %%
# Criamos um Gráfico de Barras para visualizar melhor as informações
sns.set()
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.figure(figsize=(7,5))

plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

ax = sns.barplot(data=dados_resultados_moa_Top_10, 
                 y=dados_resultados_moa_Top_10.index, 
                 x='totais', 
                 palette="BuGn_d")

# Melhorando as fontes do Título e dos eixos
ax.set_title('Top 10 das ações do MOA', fontdict={'fontsize':20, 'fontweight':'bold'}, pad=15) 
ax.set_ylabel('Ações', fontdict={'fontsize':14})
ax.set_xlabel('Contagem', fontdict={'fontsize':14})

plt.show()

# %% [markdown]
# Agora vamos analisar as linhas da base de dados para verificar se elas foram ativadas? Em caso positivo, quantas vezes isso ocorreu?

# %%
dados_resultado.drop('id', axis=1).sum(axis=1)
# Out:
# 0        3.0
# 1        0.0
# 2        7.0
# 3        0.0
# 4        3.0
#         ...
# 23809    3.0
# 23810    3.0
# 23811    0.0
# 23812    3.0
# 23813    0.0
# Length: 23814, dtype: float64

# %% [markdown]
# Observamos que algumas linhas foram ativadas uma única vez, a linha 2 por exemplo foi ativada 3 vezes e há linhas que não foram ativadas, representadas pelo 0.
#
# Dentre as linhas que resultaram em 0, precisamos se foi 'com_controle' ou a droga não ativou.

# %%
#adicionando a coluna com número de MOA a base resultados
dados_resultado['n_moa'] = dados_resultado.drop('id', axis=1).sum(axis=1)
dados_resultado.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...    3.0       True
# 1  id_000779bfc                            0  ...    0.0      False
# 2  id_000a6266a                            0  ...    7.0       True
# 3  id_0015fd391                            0  ...    0.0      False
# 4  id_001626bd3                            0  ...    3.0       True
#
# [5 rows x 209 columns]

# %%
#adicionando uma coluna informando se a linha foi ativa ou não
dados_resultado['ativo_moa'] = dados_resultado['n_moa'] != 0
dados_resultado.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...    3.0       True
# 1  id_000779bfc                            0  ...    0.0      False
# 2  id_000a6266a                            0  ...    7.0       True
# 3  id_0015fd391                            0  ...    0.0      False
# 4  id_001626bd3                            0  ...    3.0       True
#
# [5 rows x 209 columns]

# %%
#Agora combinando as duas bases 
dados_combinado = pd.merge(dados, dados_resultado[['id', 'n_moa', 'ativo_moa']], on='id')
dados_combinado.head()
# Out:
#              id tratamento  tempo dose  ...     c98     c99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176    3.0       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371    0.0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931    7.0       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154    0.0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125    3.0       True
#
# [5 rows x 879 columns]

# %%
#Filtrando esta base com o tratamento sendo 'com controle' e os ativos = False
dados_combinado.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
#Filtramos para saber o total de ativos False
dados_combinado.query('ativo_moa == False')['n_moa'].value_counts()
# Out:
# 0.0    9367
# Name: n_moa, dtype: int64

# %% [markdown]
# Após estes passos, concluimos que todos os experimentos ministrados 'com controle' não sofreram nenhum tipo de ativação.
#
# Porém, observamos que há tratamentos 'com droga' que não ativaram o MOA. O que se confirma a seguir:

# %%
dados_combinado.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %% [markdown]
# Isso nos mostra que das mais de 21mil substâncias ministradas 'com droga' 7501 não ativaram o MOA.
#
# Vamos usar o boxplot para inferir mais algumas análises da distribuição, para isso usaremos um gene específico 'g0'.

# %%
# Selecionano os 10 principais compostos
composto_principal = dados_combinado['composto'].value_counts().index[:11]
composto_principal
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee',
#        'd08af5d4b', '292ab2c28', 'd50f18348', 'd1b47f29d', '67c879e79',
#        '52d1e6f43'],
#       dtype='object')

# %%
#plotando o gráfico
sns.set()
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.figure(figsize=(12,8))

ax = sns.boxplot(data=dados_combinado.query('composto in @composto_principal'), 
                 y='g0', 
                 x='composto')

# Melhorando as fontes do Título e dos eixos
ax.set_title('Boxplot da ação de 10 compostos no g0', fontdict={'fontsize':20, 'fontweight':'bold'}, pad=15) 
ax.set_ylabel('g0', fontdict={'fontsize':14})
ax.set_xlabel('Compostos', fontdict={'fontsize':14})

plt.show()

# %%
#plotando o gráfico agora levando em conta a coluna tratamento
sns.set()
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.figure(figsize=(12,8))

ax = sns.boxplot(data=dados_combinado.query('composto in @composto_principal'), 
                 y='g0', 
                 x='composto',
                 hue = 'ativo_moa')

# Melhorando as fontes do Título e dos eixos
ax.set_title('Boxplot da ação de 10 compostos no g0', fontdict={'fontsize':20, 'fontweight':'bold'}, pad=15) 
ax.set_ylabel('g0', fontdict={'fontsize':14})
ax.set_xlabel('Compostos', fontdict={'fontsize':14})


plt.show()

# %% [markdown]
# ### Desafio 02: Criar a coluna eh_controle para quando na linha tratamento == com_controle

# %% [markdown]
# Para inserir uma coluna lógica para o tipo de tratamento.
#
# Usamos os seguinte passos:

# %%
# Testamos se a lógica esta correta
(dados_combinado['tratamento'] == 'com_controle')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23809    False
# 23810    False
# 23811     True
# 23812    False
# 23813    False
# Name: tratamento, Length: 23814, dtype: bool

# %%
# Acrescentamos o resultado anterior na nossa base
dados_tratamento = {'com_controle': 1,
                    'com_droga': 0}
dados_combinado['eh_controle'] = (dados_combinado['tratamento'].replace(dados_tratamento))
dados_combinado.tail(10)
# Out:
#                  id    tratamento  tempo  ... n_moa ativo_moa  eh_controle
# 23804  id_fff506720     com_droga     24  ...   0.0     False            0
# 23805  id_fff6df1c5     com_droga     48  ...   3.0      True            0
# 23806  id_fff790a17     com_droga     48  ...   0.0     False            0
# 23807  id_fff7e6992     com_droga     48  ...   3.0      True            0
# 23808  id_fff8c2444     com_droga     72  ...   3.0      True            0
# 23809  id_fffb1ceed     com_droga     24  ...   3.0      True            0
# 23810  id_fffb70c0c     com_droga     24  ...   3.0      True            0
# 23811  id_fffc1c3f4  com_controle     48  ...   0.0     False            1
# 23812  id_fffcb9e7c     com_droga     24  ...   3.0      True            0
# 23813  id_ffffdd77b     com_droga     72  ...   0.0     False            0
#
# [10 rows x 880 columns]

# %% [markdown]
# ### Desafio 03: Criar três colunas para indicar o tempo 24, 48, 72 horas.

# %%
# a função get_dummies transforma dados categóricos para binários
dados_combinado = pd.get_dummies(dados_combinado, columns=['tempo'])
dados_combinado.head()
# Out:
#              id tratamento dose  ... tempo_24  tempo_48  tempo_72
# 0  id_000644bb2  com_droga   D1  ...        1         0         0
# 1  id_000779bfc  com_droga   D1  ...        0         0         1
# 2  id_000a6266a  com_droga   D1  ...        0         1         0
# 3  id_0015fd391  com_droga   D1  ...        0         1         0
# 4  id_001626bd3  com_droga   D2  ...        0         0         1
#
# [5 rows x 882 columns]

# %% [markdown]
# ### Desafio 04: Estudar sobre combinações de dataframes DF
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %% [markdown]
# ### Desafio 05: Fazer análise mais detalhada considerando tempo e dose, para comparar as distribuições (Escolher uma dorga e comparar com o controle)

# %% [markdown]
# Para este desafio, vamos pegar a variável de controle sob o código 'cacb2b860' e a droga de maior frequência '87d714366'.

# %%
compostos_de_estudo = composto_principal[:2]
dados_compostos_de_estudo = dados.query('composto in @compostos_de_estudo')
dados_compostos_de_estudo.tail()
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 23776  id_ff9d0a022     com_droga     24   D2  ... -7.5290 -6.3180 -5.7010 -3.5610
# 23791  id_ffd1fd119     com_droga     72   D2  ... -9.9660 -8.6420 -9.9660 -4.6050
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
#
# [5 rows x 877 columns]

# %% [markdown]
# Agora vamos analisar o comportamento destes compostos no 'g0' levando em conta a dose aplicada e o tempo do experimento.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 8), sharey= True)
fig.suptitle('Comportamento dos "g0" com ou sem o composto por dose e ao longo do tempo ', fontsize=20)

#g0 relativo a dose
ax1.set_title('g0', fontsize=14)
sns.boxplot(y= 'g0', ax=ax1, x='tratamento' , data=dados_compostos_de_estudo, hue= 'dose')
ax1.set_ylabel('Expressões gênicas', fontsize=14) 

#go relativo ao tempo
ax2.set_title('g0', fontsize=14)
sns.boxplot(y= 'g0', ax=ax2, x='tratamento' , data=dados_compostos_de_estudo, hue='tempo')
ax2.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# Concluimos que o passar do tempo não é tão relevante quando a droga recebe a droga de 'controle', o que era de se esperar. Já no experimento com uma droga, observamos um rápido aumento na vida ou morte das celulas no intervalo de 24 a 48horas.
#
# O efeito das doses também não trás alterações significativas no genes sob efeito do 'com controle' e uma alteração mais significativa quando administra-se uma droga.

# %% [markdown]
# ### Desafio 06: Descobrir se temos algum composto que dependendo da configuração do experimento, ativa ou não algum MOA.

# %%
#Selecionamos todos os composto que tiveram o MOA ativo
ativo = dados_combinado.query('ativo_moa == True')

# %%
# Selecionamos todos os compostos que Não tiveram o MOA ativo
nao_ativo = dados_combinado.query('ativo_moa == False')

# %%
# Fazendo uma varredura pelas duas listas para buscar casos duplicados 
casos_duplicados = []

for i in ativo['composto']:
  if i in nao_ativo['composto']:
    casos_duplicados.append(i)
print(len(casos_duplicados))
# Out:
# 0

# %%
dados_combinado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23814 entries, 0 to 23813
# Columns: 882 entries, id to tempo_72
# dtypes: bool(1), float64(873), int64(1), object(4), uint8(3)
# memory usage: 159.8+ MB

# %% [markdown]
# Após uma separação entre casos ativos e não ativos, observamos que não há compostos duplicados nas duas situações.

# %% [markdown]
# ### Desafio 07: Descobrir se temos algum composto que dependendo da configuração do experimento, ativa MOAs diferentes

# %%
dados_resultado.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...    3.0       True
# 1  id_000779bfc                            0  ...    0.0      False
# 2  id_000a6266a                            0  ...    7.0       True
# 3  id_0015fd391                            0  ...    0.0      False
# 4  id_001626bd3                            0  ...    3.0       True
#
# [5 rows x 209 columns]

# %%
# Nos compostos ativos, filtraremos os com MOA > 1
dados_teste = pd.merge(dados_resultado, dados[['id', 'composto']], on='id').groupby(['composto']).nunique()
dados_teste
# Out:
#            id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# composto                                    ...
# 00199ff52   6                            1  ...      1          1
# 00251fc41   6                            1  ...      1          1
# 00321ea80  12                            1  ...      1          1
# 0034c0847   6                            1  ...      1          1
# 0060e686f   6                            1  ...      1          1
# ...        ..                          ...  ...    ...        ...
# ff9565933   6                            1  ...      1          1
# ffd66e220   6                            1  ...      1          1
# ffe357f8f   1                            1  ...      1          1
# ffed8e1c9   6                            1  ...      1          1
# fff7d208d   6                            1  ...      1          1
#
# [3289 rows x 209 columns]

# %%
dados_teste.query('n_moa > 1')
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# Concluimos que não há composto que dependendo da configuração ativam MOAs distintos.

# %% [markdown]
# ### Desafios 08: Resumo do que você aprendeu.

# %% [markdown]
#  Nessa aula apresendemos a investigamos uma nova base dados (resultados). Analisar um determinado composto pode ativar mais do que um único MOA,
# aprendemos a juntar base de dados. E também criamos o boxplot para observar as diferenças de alguns compostos nos genes.

# %% [markdown]
# # Aula 5

# %% [markdown]
# Seja bem-vindo e bem-vinda à última aula da Imersão Dados 3ª Edição!
#
# Nesta aula, finalmente vamos criar o nosso primeiro modelo de Machine Learning para classificar um novo composto com o intuito de prever se o MoA foi ativado ou não. Para isso, vamos usar a famosa biblioteca scikit-learn para testar a regressão logística e entender o funcionamento de uma árvore de decisão (AD). Além disso, discutiremos problemas importantes como o overfit.

# %% [markdown]
# Olá Cientista!
#
#
# Seja bem vindo e bem vinda à aula 05. Parabéns por ter chegado até aqui!
#
# Na última aula nós analisamos separadamente, através de algumas técnicas, os efeitos em cada gene do grupo "com_tratamento" usados.
# Além disso utilizamos o boxplot para nos auxiliar na análise de forma visual tirando algumas conclusões muito interessantes.
#
# Você conseguiu fazer todos os desafios? Então vamos mergulhar juntos na aula 05!
#
# Nesta aula, vamos entender e aplicar o Machine Learning. Primeiramente, vamos entender o que o ML significa. Existem muitas definições para o termo, mas aqui, vamos trazer a definição clássica de um renomado e importante cientista da computação, o Arthur Samuel.
#
# ***“Machine learning is the field of study that gives computers the ability to learn without being explicitly programmed” – (definição clássica de Arthur Samuel, cientista da computação, 1959)***
#
# *Tradução livre: "Machine Learning é um campo de estudo que dá aos computadores a habilidade de aprender sem terem sido programados para tal."*
#
# Podemos interpretar a definição de Samuel, da seguinte forma: para que um computador reconheça determinada imagem, não precisamos passar um conjunto de regras, mostrar vários exemplos é suficiente para que o computador classifique suas imagens. Sendo assim, temos dois fatores determinantes neste processo: um conjunto de dados suficientemente grande e um poder computacional elevado. Por isso, até os anos 2000, era bem difícil encontrarmos problemas significantes resolvidos através do Machine Learning. Mas, a partir de 2009, empresas como a Netflix e Amazon, começaram a resolver problemas reais com o processamento dos dados através no ML, isso porque tinham uma infinidade de dados disponíveis e alto poder computacional.
#
# E quais problemas podemos resolver com esse tipo de algoritmo? Existem diversos casos em que podemos aplicá-los mas, vamos subdividir em dois grandes grupos:
#
#     - Problemas em que somos muito bons em resolver mas o Machine Learning, leva essa produção à um nível industrial, como é o caso da classificação de imagens
#     - Problemas em que não somos tão bons em resolver e o Machine Learning pode tomar uma melhor decisão em relação à nossa (imparcialidade, pode ser um fator), como é o caso da concessão de crédito.
#
# Mas como o Machine Learning vai ser aplicado no nosso problema?
# Bom, utilizando a nossa base de dados ```dados_combinados```, o primeiro problema que pensamos em resolver é: **dado os experimentos, queremos saber se qualquer mecanismo de ação foi ativado ou não ativado.** Ou seja, este caso é um problema de classificação binária.
#
# Mas, também podemos pensar se **dado os experimentos, queremos saber se um determinado mecanismo de ação foi ativado, recebendo como resposta, o composto relacionado**. E aqui, temos um problema de classificação multiclasse, já que cada composto químico é considerado uma classe diferente.

# %%
dados_combinado.head()
# Out:
#              id tratamento  tempo dose  ...     c98     c99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %% [markdown]
# Mas, na nossa base ```dados_resultados``` nós encontramos o ID do composto e quais mecanismos de ação foram acionados por determinado experimento. Aqui, como um composto pode acionar mais de um mecanismo, nós teremos uma classificação multilabel (quando uma única instância pode ter mais de uma classe associada) e, através de um algoritmo de Machine Learning nós também podemos resolver este problema: **não somente ter como retorno se um mecanismo de ação foi ativado mas qual ou quais são estes mecanismos**.
#
# É importante lembrar que nossas bases de dados estão separadas com um propósito. A segunda ```dados_resultados``` é como se fosse a resposta da primeira e foi construída por cientistas que analisaram o efeito de um determinado composto nos mais de 700 genes. Esse conhecimento, virou uma base de dados com o passar dos anos e é fruto de análise científica.
#
# E o papel de um modelo de ML neste caso é, a partir de todo esforço humano empenhado por vários anos para entender e tabular qual efeito de um composto quimíco em uma determinada expressão gênica, ser treinado e aprender, ou seja, ser capaz de produzir resultados compatíveis com aqueles feitos pelos(as) próprios(as) cientistas.
#
# Aqui na imersão, vamos começar resolvendo o problema menos complexo, a classificação binária: **dado os experimentos, queremos saber se QUALQUER mecanismo de ação foi ativado ou não**. Basicamente, queremos que o modelo faça predições compatível com a última coluna da nossa base de dados ```dados_combinados```, a ```ativo_moa```.

# %%
dados_resultado.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %% [markdown]
# As etapas lógicas do nosso processo é:
#
#     Dado um composto -> temos a nossa assinatura celular (```g e c```) -> analisamos o(s) mecanismo(s) de ação ativados (MoA)
#
# Mas, a nossa pergunta a ser respondida é, **"Dado um composto e uma assinatura celular, houve algum MoA ativado?"** Então, as etapas lógicas passam a ser:
#
#     Composto -> assinatura celular -> MoA ativado?
#
# E como nosso modelo vai aprender a partir da nosa base de dados?
#
#     Composto 1 -> Assinatura A -> MoA = 1
#     Composto 2 -> Assinatura B -> MoA = 0
#     Composto 3 -> Assinatura C -> MoA = 1
#     ...
#     Composto N -> Assinatura N -> MoA = 0
#
# Ou seja, toda a nossa base de dados ```dados_combinados``` será a fonte de aprendizado do nosso modelo. Onde, cada experimento (linha) representa um exemplo (assinatura) já que temos a reunião de todas as informações necessárias para criar a nossa classificação binária e, terá como variável resposta, também chamada de target, a coluna ```ativo_moa```, uma variável binária (0, 1).
#
# E, por fim, o nosso modelo deverá ser capaz de resolver o seguinte problema:
#
#     Composto candidato -> Assinatura X -> MoA = 1 OU MoA = 0?
#
# Existem diversas técnicas de ML que são capazes de solucionar o nosso problema mas aqui, vamos usar a **Regressão Logística** e, essa técnica já está implementada em uma biblioteca bastante usada e bem importante para ML no Python, o [Scikit-Learn](https://scikit-learn.org/stable/).
#
# Sugerimos que você leia essa documentação e se familiarize com esta biblioteca, ela será muito importante na sua trajetória como Cientista de Dados. E, clicando em "Classification" na página inicial, encontramos, no primeiro capítulo, chamado "Linear Models", o nosso subtítulo de interesse: [**"1.1.11 Logistic Regression"**](https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression).

# %% [markdown]
# Quando implementamos um modelo de classificação, precisamos separar a nossa base de dados em base de treino e base de teste. A base de treino, vai ser onde o nosso modelo vai aprender e, a base de teste serve para a verificação do aprendizado do modelo, ou seja, poderemos entender se, de fato, as previsões do nosso modelo estão de acordo com o esperado.
#
# Não podemos treinar e testar o modelo com o mesmo conjunto de dados porque, seria muito mais fácil dele prever corretamente. A base de dados de teste, funciona como um novo conjunto onde poderemos medir o quanto o nosso modelo está acertando, dado que já temos a variável resposta real.
#
# Para fazer esta divisão, usamos uma função do Scikit-Learn chamada ```train_teste_split``` (como já aprendemos, para usar uma biblioteca ou função, precisamos, primeiramente, fazer a importação padrão e, neste caso, usaremos ```from sklearn.model_selection import train_test_split```).
#
# Para fazer a divisão da base de dados, é necessário definir qual será o nosso ```x``` e o nosso ```y```. Um modelo matemático, define um ```y``` em função de um ```x```, ou seja, ```f(x) = y```. Neste projeto, o nosso ```y``` será o target, ```ativo_moa``` e, ele será definido a partir de uma assinatura (conjunto composto por ```g``` + ```c``` ou , expressão gênica + viabilidade celular).
#
# Assim, teremos:
#
#     x = dados_combinados.select_dtypes('float64')  ->  toda a base de dados que tem os valores com o formato, ```float64```, no nosso caso, todas as variáveis ```g``` e ```c```
#
#     y = dados_combinados['ativo_moa']  ->  apenas a coluna target, ou seja, ```ativo_moa```
#
# Para o ```train_test_split``` definiremos:
#
#     x_treino, x_teste, y_treino, y_teste
#
# E a função receberá como parâmetro:
#
#     train_test_split(x, y, test_size = 0.2)
#
# Onde,
#
#     x -> base de dados definida como x, no nosso caso, todas as variáveis ```g``` e ```c```
#
#     y -> variável resposta, no nosso caso, ```ativo_moa```
#
#     teste_size = 0.2 -> tamanho que definimos para a base de teste
#
# A proporção entre treino e teste, varia de acordo com o volume de dados que temos. Mas, usualmente, encontramos proporções 30/70, 25/75 ou 20/80. Aqui, definimos como 0,2 ou 20%, isso significa que a base de treino será composta pelos 80% restante.

# %%
from sklearn.model_selection import train_test_split

x = dados_combinado.select_dtypes('float64')
y = dados_combinado['ativo_moa']

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2)

# %% [markdown]
# Agora, podemos fazer a nossa primeira regressão logística.
#
# O primeiro passo, é definir o nosso ```x```, ```y``` e o ```x_treino, x_teste, y_treino, y_teste``` do ```train_test_split```.
#
# Após isso, definimos um nome para o nosso modelo (```modelo_rlogistica```) e declaramos a função ```LogisticRegression()```. Acrescentamos um parâmetro ```max_iter = 1000``` no modelo para que ele seja capaz de convergir para um resultado e assim, não recebemos nenhum warning no resultado.
#
# Em seguida, ajustamos o modelo com o ```.fit(x_treino, y_treino)``` (lembrando que os argumentos desta função são ```x``` e ```y``` e, usamos ```x_treino``` e ```y_treino``` porque será através dessas bases que o algoritmo aprenderá).
#
# E, por fim, usamos a função ```.score(x_teste, y_teste)``` para verificar como o nosso modelo ajustado está se saindo nos dados de teste. O ```score()```calcula a acurácia, ou seja, quantas predições o nosso modelo acertou na base de teste.
#
# Como resultado, temos o valor da acurácia: ~0,627. Então, concluímos que o nosso modelo está acertando ~62% das previsões (caso tivéssemos 100 experimentos, o modelo acertaria 62 casos e erraria 38 casos).
#
# Mas, como podemos estabelecer se este é um bom valor de acurácia ou não?

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

x = dados_combinado.select_dtypes('float64')
y = dados_combinado['ativo_moa']

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify = y, random_state = 376)

modelo_rlogistica = LogisticRegression(max_iter = 1000)
modelo_rlogistica.fit(x_treino, y_treino)
modelo_rlogistica.score(x_teste, y_teste)
# Out:
# 0.6267058576527399

# %% [markdown]
# Para estabelecer se temos um bom valor de acurácia, precisamos de uma base comparativa, quer dizer, preciso dos resultados de um outro modelo para entender se estamos acertando mais ou menos casos.
#
# Para isso, o Scikit-Learn, já tem implementado alguns algoritmos que fazer modelos menos complexos e que podem ser usados como base comparativa. Neste caso, vamos usar o ```DummyClassifier```.
#
# O processo para ajustar este modelo é muito parecido com aquele que usamos para a regressão logística: dividimos a base em treino e teste, definimos um nome para esse modelo e o instanciamos, o ajustamos com os dados de treino e, ao final, verificamos a acurácia com o conjunto teste.
#
# Ao instanciarmos o ```DummyClassifier```, precisamos definir a estratégia que ele usará para fazer o ajuste do modelo. No nosso caso, definimos a estratégia será os dados mais frequentes, isso quer dizer que: dado o valor mais frequente da nossa variável resposta (```ativo_moa```), o modelo Dummy vai chutar que todos os eventos da base de dados assumem aquele valor no target. Assim, temos: ```DummyClassifier('most_frequent')```.
#
# Nesse momento, para calcular a acurácia, vamos usar outra estratégia, a função ```accuracy_score``` também do Scikit-Learn. Ela receberá como parâmetros a base teste da variável resposta (```y_teste```) e as previsões do modelo que, até o momento ainda não calculamos.
# Para calcular as previsões, usamos o ```.predict()``` da mesma biblioteca que, receberá como parâmetro a base ```x_teste```.
# Por fim, o cálculo da acurácia será:
#
#     previsao_dummy = modelo_dummy.predict(x_teste)
#     accuracy_score(y_teste, previsao_dummy)
#
# A acurácia do ```DummyClassifier```foi de ~60,7%, isso significa que nosso modelo ```LogisticRegression``` teve um desempenho um pouco melhor.

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

modelo_dummy = DummyClassifier('most_frequent')
modelo_dummy.fit(x_treino, y_treino)
previsao_dummy = modelo_dummy.predict(x_teste)
accuracy_score(y_teste, previsao_dummy)
# Out:
# 0.6067604450976275

# %% [markdown]
# Podemos entender a acurácia do ```DummyClassifier``` se fizermos um ```value_counts``` normalizado e então verificamos que a proporção entre a classe 0 e a classe 1 é 60/30, ou seja, o valor mais frequente (estratégia usada no ```DummyClassifier```) representa 60% da base de dados.
# Isso quer dizer que, caso o modelo chutasse a mesma classe para todos os eventos da base de teste, teríamos um acerto de 60% dos casos.

# %%
dados_combinado['ativo_moa'].value_counts(normalize = True)
# Out:
# True     0.60666
# False    0.39334
# Name: ativo_moa, dtype: float64

# %% [markdown]
# Entretanto, toda vez que rodamos tanto a nossa regressão logística, quanto o nosso dummy classifier, recebemos como retorno um valor diferente de acurácia, apesar de em muitos casos, serem próximos.
#
# O ```train_test_split``` a base de dados em subconjuntos aleatórios de treino e teste. Isso significa que toda vez que você executá-lo, você obterá um resultado diferente.
#
# Por outro lado, se você declarar o parâmetro ```random_state = n```, poderá garantir que a saída de todas as execuções será igual, ou seja, sua divisão será sempre a mesma. Não importa qual número você escolherá para o ```random_state```, o importante é que toda vez que você usá-lo, sempre terá a mesma saída.
#
# Além do ```random_state```, existe mais um parâmetro bem importante que deve ser levado em consideração na divisão da nossa base de dados, o ```stratify```.
#
# Se repararmos na divisão da variável ```ativo_moa```, entre ```true``` e ```false```, percebemos que segue um balanceamento 60/40. E, é do nosso interesse que as bases de treino e teste sigam, além de uma divisão reprodutível (garantida com ```random_state```), a proporção original do conjunto de dados. Assim, atribuimos ```stratify = coluna```, onde ```coluna = nome da coluna que o stratify deve levar em consideração a proporção de classes```. No nosso caso, usamos ```stratify = y```, pois ```y``` é a nossa variável resposta e, é dela que o stratify deve considerar a proporção: 60/40.
#
# Esses parâmetros são úteis, porque garantimos que os resultados são reproduzíveis e compatíveis, independente do modelo (qual técnica, por exemplo, regressão logística, dummy classifier, árvore de decisão e etc) que vamos treinar e testar a partir desta divisão.
#
# Ou seja, ao final, nosso ```train_teste_split``` ficará:
#
#     x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

# %% [markdown]
# Nesse momento, temos interesse a explorar outras técnicas de modelagem para comparar os resultados obtidos e ver qual o melhor algoritmo que conseguimos produzir.
#
# Sendo assim, vamos testar uma nova técnica: a árvore de decisão.
#
# Novamente, a sequência lógica para ajustar esse novo modelo é muito parecida com que estávamos vendo até o momento: definimos as bases ```x``` e ```y```, fazemos o ```train_test_split```, declaramos o novo modelo, ajustamos e verificamos a acurácia.
#
# Aqui, vamos usar o ```DecisionTreeClassifier```, também da biblioteca Scikit-Learn. O único parâmetro que vamos declarar para esta função será o ```max_depth = 3``` mas, vamos explorar seu significado a seguir.
#
# Como resultado, temos uma acurácia (calculada a partir da base de teste) de ~0,61% e, é um pouco menos do que a acurácia obtida com a regressão logística.

# %%
from sklearn.tree import DecisionTreeClassifier

x = dados_combinado.select_dtypes('float64')
y = dados_combinado['ativo_moa']

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify = y, random_state = 376)

modelo_arvore = DecisionTreeClassifier(max_depth = 3)
modelo_arvore.fit(x_treino, y_treino)
modelo_arvore.score(x_teste, y_teste)
# Out:
# 0.6105395758975436

# %% [markdown]
# Agora, vamos entender melhor como funciona uma árvore de decisão e o que significa o parâmetro ```max_depth = 3```.
# Plotamos uma imagem que representa o nosso modelo e, nesse momento, é importante que você não se apegue ao código que usamos para isso. O que realmente é relevante é entender o algoritmo!
#
# A figura é dividida em 4 níveis e, o primeiro nível (estamos considerando a orientação de cima para baixo), é composto por apenas um quadro que é chamado de **nó raíz** ou somente **raíz** e ele tem como regras, os melhores atributos que podem dividir a nossa base de dados em dois conjuntos distintos (lembrando que nosso objetivo é separar a nossa base de dados em **mecanismo de ação ativado ou não ativado**).
#
# Entre o primeiro e o segundo nível (e nos demais níveis), temos duas setas: uma para a direita e outra para a esquerda. Essas setas são chamadas de **ramos** e subdividem o nível acima em dois outros conjuntos que separam novamente os dados em **mecanismo de ação ativado ou não ativado**, a partir de uma decisão.
#
# O último nível da árvore (mais abaixo), apresenta n quadros que apresentam características que devem ser levadas em conta na hora da classificação e se dividem em ```class = ativado``` e ```class = não ativado```. Esse nível não apresenta mais ramificações e, esses quadros são chamados de **folhas**.
#
# Se reparmos, a nossa árvore tem 3 níveis de decisão a partir da raíz e é exatamente isso que o parâmetro ```max_depth```representa: a profundidade da árvore.

# %%
from sklearn import tree

fig, ax = plt.subplots(figsize=(15, 10), facecolor='k')
tree.plot_tree(modelo_arvore,
               ax=ax,
               fontsize=10,
               rounded=True,
               filled=True,
               feature_names=x_treino.columns,
               class_names=['Não Ativado', 'Ativado'])

plt.show()

# %% [markdown]
# Como vimos, o desempenho do nosso novo modelo com apenas 3 camadas de decisão não foi tão satisfatório assim. Por isso, vamos variar o ```max_depth``` dentro de um intervalo de valores (range) e comparar os resultados obtidos.
#
# O processo para obter os valores que queremos, é sempre o mesmo. Por isso, vamos criar um loop ou um laço de repetição (um loop, executa um bloco de código em repetição enquanto uma condição é atendida).
#
# Então, após fazermos a separação da base de dados em ```x``` e ```y``` e dividí-las no ```train_test_split```, vamos criar um ```for``` para que nosso modelo seja treinado e testado em repetição dentro de um range. Para isso, faremos:
#
#     teste=[]  ->  criando lista para armazenar os resultados da acurácia nos dados de teste
#     treino=[]  ->  criando lista para armazenar os resultados da acurácia nos dados de treino
#     for i in range(1,15):  ->  estabelecendo condição que deve ser atendida (i) e range de valor (range(1, 15))
#         modelo_arvore = DecisionTreeClassifier(max_depth = i)  ->  instanciando modelo que será treinado e definindo max_depth = i, ou seja, estamos variando a profundidade da nossa árvore
#         modelo_arvore.fit(x_treino, y_treino)  ->  ajustando o modelo a partir das bases de treino
#         teste.append(modelo_arvore.score(x_teste, y_teste))  ->  armazenando os resultados de acurácia de teste dos modelos produzidos na lista 'teste'
#         treino.append(modelo_arvore.score(x_treino, y_treino))  ->  armazenando os resultados de acurácia de treino dos modelos produzidos na lista 'treino'

# %%
from sklearn.tree import DecisionTreeClassifier

x = dados_combinado.select_dtypes('float64')
y = dados_combinado['ativo_moa']

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify = y, random_state = 376)

teste = []
treino = []

for i in range(1, 15):
  modelo_arvore = DecisionTreeClassifier(max_depth = i)
  modelo_arvore.fit(x_treino, y_treino)
  teste.append(modelo_arvore.score(x_teste, y_teste))
  treino.append(modelo_arvore.score(x_treino, y_treino))

# %% [markdown]
# Quando chamamos as saídas do nosso ```for``` (```teste``` e ```treino```), podemos observar um comportamento um pouco estranho: enquanto nos dados de teste, o valor da nossa acurácia vai caindo, nos dados de treino, esse valor vai aumentando.

# %%
teste
# Out:
# [0.6067604450976275,
#  0.6067604450976275,
#  0.6105395758975436,
#  0.6204073063195465,
#  0.62019735460844,
#  0.6172580306529498,
#  0.6199874028973336,
#  0.6212471131639723,
#  0.6176779340751627,
#  0.6134788998530338,
#  0.6082301070753726,
#  0.598992231786689,
#  0.5996220869200084,
#  0.5987822800755827]

# %%
treino
# Out:
# [0.6066348223190384,
#  0.6066348223190384,
#  0.6211222508004829,
#  0.6360820954280615,
#  0.6412261823526324,
#  0.6489423127394888,
#  0.6605427536612252,
#  0.6707259461445594,
#  0.689570101307018,
#  0.7067870452994593,
#  0.7294105296309905,
#  0.7531363183035011,
#  0.7769145976589156,
#  0.7993281192588315]

# %% [markdown]
# Para investigar o que aconteceu, vamos plotar um gráfico para entender o comportamento combinado dessas listas.
#
# Usaremos o ```lineplot``` do Seaborn para construir essa visualização.
# Como parâmetros, teremos:
#
#     x = range(1, 15)   ->  intervalo que usamos no for
#     y = teste e y = treino  ->  listas criamos no for e será usada no eixo y do gráfico
#     label = 'teste' e label = 'teste'  ->  etiqueta para identificar as duas linhas que estarão no gráfico
#
# Observando o gráfico produzido, podemos perceber que, inicialmente, os valores de treino e teste são muito próximos mas, conforme vamos aumentando o range, o valor da acurácia para os dados de treino aumentam muito enquanto, esse mesmo valor para os dados de teste, vai caindo (as linhas vão se afastando).
#
# Isso significa que, conforme aumentamos a profundidade da nossa árvore de decisão, a classificação para os dados de treino ficam muito boas pois, ela consegue captar muito bem as características desses dados. Mas, em contrapartida, o modelo fica tão bom os dados de treino que, quando apresentamos um novo conjunto de dados (teste), ele não consegue generalizar tão bem e assim, temos uma acurácia em queda.
#
# Esse problema de um modelo com performance muito boa nos dados de treino mas performance em queda nos dados de teste, é muito conhecido na ciência de dados e chamamos de **overfitting**.
#
# Então, conseguimos perceber que, para melhorar o nosso modelo, não é suficiente somente aumentar a profundidade da árvore de decisão e assim, precisamos traçar uma outra etratégia para melhorar a performance do nosso modelo.
#
# Nesse momento, vamos testar uma nova técnica de modelagem: o Random Forest.
# O que este modelo faz é criar várias árvores de decisões na qual ele considera amostras aleatórias do nosso conjunto total.

# %%
sns.lineplot(x = range(1, 15), y = teste, label = 'teste')
sns.lineplot(x = range(1, 15), y = treino, label = 'treino')

# %% [markdown]
# A função que treina um modelo de Random Forest (```RandomForestClassifier()```) não aceita que tenhamos variáveis em formato de string.
# Por isso, precisamos tratar as variáveis que são strings e transformá-las em números (ou no formato float64).
#
# Para fazer essa transformação, vamos usar uma função do Pandas, chamada ```get_dummies``` e nela, declaramos a coluna que queremos que seja transformada. Por exemplo, aqui, usamos:
#
#     pd.get_dummies(dados_combinados['tratamento'])
#
# Isso porque, nossa intenção é transformar a coluna ```tratamento``` da base ```dados_combinados``` em dados numéricos.
#
# Para fazer a transformação desejada, o ```get_dummies``` pega todas as categorias de uma variável e as transforma em novas colunas binárias.
# Por exemplo:
#
# A variável ```tratamento``` apresenta duas categorias ```com_controle``` e ```sem_controle```. Quando aplicamos o ```get_dummies```, ele cria duas novas colunas binárias e análogas as categorias.
# Se temos um evento que apresentava na coluna original a marcação ```com_droga```, agora ela apresentará valor 0 na coluna ```com_controle``` e valor 1 na coluna ```com_droga``` e vice-versa.

# %%
pd.get_dummies(dados_combinado['tratamento'])
# Out:
#        com_controle  com_droga
# 0                 0          1
# 1                 0          1
# 2                 0          1
# 3                 0          1
# 4                 0          1
# ...             ...        ...
# 23809             0          1
# 23810             0          1
# 23811             1          0
# 23812             0          1
# 23813             0          1
#
# [23814 rows x 2 columns]

# %% [markdown]
# Agora que entendemos como o ```get_dummies``` funciona, podemos transformar todas as nossas variáveis de interesse: ```tratamento```, ```dose``` e ```tempo```.
#
# Para isso, declaramos a base de dados completa e, no parâmetro ```columns```, listamos as variáveis que devem ser transformadas. Assim teremos:
#
#     pd.get_dummies(dados_combinados, columns=['tratamento', 'dose', 'tempo'])

# %%
pd.get_dummies(dados_combinado, columns=['tratamento', 'dose', 'tempo'])
# Out:
#                  id   composto      g0  ...  tempo_24  tempo_48  tempo_72
# 0      id_000644bb2  b68db1d53  1.0620  ...         1         0         0
# 1      id_000779bfc  df89a8e5a  0.0743  ...         0         0         1
# 2      id_000a6266a  18bb41b2c  0.6280  ...         0         1         0
# 3      id_0015fd391  8c7f86626 -0.5138  ...         0         1         0
# 4      id_001626bd3  7cbed3131 -0.3254  ...         0         0         1
# ...             ...        ...     ...  ...       ...       ...       ...
# 23809  id_fffb1ceed  df1d0a5a1  0.1394  ...         1         0         0
# 23810  id_fffb70c0c  ecf3b6b74 -1.3260  ...         1         0         0
# 23811  id_fffc1c3f4  cacb2b860  0.3942  ...         0         1         0
# 23812  id_fffcb9e7c  8b87a7a83  0.6660  ...         1         0         0
# 23813  id_ffffdd77b  972f41291 -0.8598  ...         0         0         1
#
# [23814 rows x 883 columns]

# %% [markdown]
# Aqui, estamos estabelecendo qual será a base de dados usada para modelar o novo algoritmo. Agora, não mais consideraremos apenas os dados genéticos, também levaremos em conta as demais variáveis, exceto as seguintes variáveis:
#
#     'id'  ->  não será relevante nesse momento pois é somente um número de identificação
#     'n_moa'  ->  não será relevante nesse momento pois é a quantidade de MoAs ativados
#     'ativo_moa'  ->  retiramos da base pois é a nossa variável resposta
#     'composto'  ->  não será relevante nesse momento pois identifica o composto usado e foge do que estamos buscando fazer
#
# Para retirar essas variáveis da nossa base de dados, usamos a função ```drop```, declaramos as variáveis a serem retiradas em forma de uma lista e identificamos que são colunas através do parâmetro ```axis = 1```.

# %%
dados_combinado.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis=1)
# Out:
#          tratamento  tempo dose      g0  ...     c96     c97     c98     c99
# 0         com_droga     24   D1  1.0620  ... -0.3981  0.2139  0.3801  0.4176
# 1         com_droga     72   D1  0.0743  ...  0.1522  0.1241  0.6077  0.7371
# 2         com_droga     48   D1  0.6280  ... -0.6417 -0.2187 -1.4080  0.6931
# 3         com_droga     48   D1 -0.5138  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4         com_droga     72   D2 -0.3254  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...    ...  ...     ...  ...     ...     ...     ...     ...
# 23809     com_droga     24   D2  0.1394  ...  0.0631  0.9171  0.5258  0.4680
# 23810     com_droga     24   D2 -1.3260  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  com_controle     48   D2  0.3942  ...  0.2256  0.7592  0.6656  0.3808
# 23812     com_droga     24   D1  0.6660  ...  0.1732  0.7015 -0.6290  0.0740
# 23813     com_droga     72   D1 -0.8598  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [23814 rows x 875 columns]

# %% [markdown]
# Enfim, podemos partir para o ajuste do nosso modelo de Random Forest.
#
# Novamente, vamos seguir as mesmas etapas lógicas anteriores. Entretando, precisamos modificar o a nossa base ```x```.
# Então faremos:
#
#     x = dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis=1)  ->  base de dados de deve ser considerada com a exclusão das colunas que determinamos anteriormente
#     x = pd.get_dummies(x, columns=['tratamento', 'dose', 'tempo'])  ->  a partir do x definido acima, fazemos a transformação com o get_dummies nas colunas com o formato de string
#
# Por fim, temos como retorno uma acurácia de ~68,0% e, ela é, aproximadamente, 7% melhor que a acurácia que conseguimos com o ```DummyClassifier```. Aqui, não podemos comparar com a regressão logística porque estamos considerando um outro conjunto de dados.
#
# É muito importante ressaltar que, apesar de termos melhorado a acurácia do nosso modelo, pensando na vida real, talvez a nossa melhora ainda não seja suficiente. Ou seja, desenvolvemos um modelo com um algoritmo de Machine Learning mas, ele ainda não é aplicável à vida real (isso quer dizer que, ainda não nos traz ganhos suficientes para sua implantação).
#
# Por outro lado, durante todo o nosso projeto, desenvolvemos modelos simples e não nos aprofundamos em todos os pontos que podem ser modificados (variáveis, parâmetros de modelos, por exemplo) a fim de otimizar a nossa generalização.
# Deixamos em destaque também a sua trajetória até aqui, certamente ela deve ser seu foco (e é também o nosso)! O resultado é apenas uma consequência disso tudo e sabemos que, para melhorá-lo você precisa persistir no estudo dessa área.
#
# A Imersão de Dados 3 foi o seu primeiro passo na ciência de dados e aqui, deixamos o convite para que você continue estudando, explorando e aprendendo todos os processos e áreas desse mundo gigantesco de possibilidades!
#
# Nos vemos em breve, cientistas!

# %%
from sklearn.ensemble import RandomForestClassifier

x = dados_combinado.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis = 1)
x = pd.get_dummies(x, columns=['tratamento', 'dose', 'tempo'])
y = dados_combinado['ativo_moa']

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify = y, random_state = 376)

modelo_randomforest = RandomForestClassifier()
modelo_randomforest.fit(x_treino, y_treino)
modelo_randomforest.score(x_teste, y_teste)
# Out:
# 0.6808733991182028

# %% [markdown]
# ## Desafios

# %% [markdown]
# ### Desafios 01: Tente outros modelos ou mude os parâmetros dos modelos que tesstamos em aula

# %% [markdown]
# Vamos usar a regressão logística novamente, mas agora usando os novos parâmentros, implementados no RandomForest.

# %%
modelo_rlogistica_melhorada = LogisticRegression(max_iter=1000)
modelo_rlogistica_melhorada.fit(x_treino, y_treino)
modelo_rlogistica_melhorada.score(x_teste, y_teste)
# Out:
# 0.6640772622296872

# %% [markdown]
# Observamos que melhoramos a acurácia em relação a nossa regressão logistica anterior em **~4%**. No entanto, ficou abaixo do RandomForest que se mostrou mais eficiente.

# %% [markdown]
# ### Desafios 02: Estude a documentação do Sklearn

# %% [markdown]
# Link: https://scikit-learn.org/

# %% [markdown]
# ### Desafios 03: Pesquisar o fluxograma 'Escolhendo o melhor modelo'

# %% [markdown]
# Efetuando a pesquisa solicitada pela Vanessa, no arquivo https://scikit-learn.org/stable/tutorial/machine_learning_map/index.html
# Concluí-se que SGDRegressor deve ser o melhor modelo a ser implementado.

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

X = dados_combinado.drop(['id', 'n_moa', 'ativo_moa', 'composto', 'tratamento'], axis=1)
y = dados_combinado['ativo_moa']

modelo_sgdregressor = make_pipeline(StandardScaler(), SGDClassifier(max_iter=1000, tol=1e-3))
modelo_sgdregressor.fit(x, y)
modelo_sgdregressor.score(x, y)
# Out:
# 0.6675485008818343

# %% [markdown]
# ### Desafios 04: Teste outras problemas (perguntas) 0, 1 ou +.

# %%
x = dados_combinado.loc[:,'g0':'c99']

# %%
y = dados['tempo'].map({24:0,48:1,72:2})
y.head()
# Out:
# 0    0
# 1    2
# 2    1
# 3    1
# 4    2
# Name: tempo, dtype: int64

# %%
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

# %%
modelo_rlogistica2 = LogisticRegression(solver='newton-cg')
modelo_rlogistica2.fit(x_treino, y_treino)
modelo_rlogistica2.score(x_teste, y_teste)
# Out:
# 0.686122191895864

# %% [markdown]
# ### Desafios 05: Escolha a droga mais utilizada e tente criar uma modelo para prever esta label.

# %%
dados_combinado['composto'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# ba08ac4bc       1
# 89ced6383       1
# ed81f4046       1
# ae2afcf9d       1
# 27fa72002       1
# Name: composto, Length: 3289, dtype: int64

# %%
teste = dados_combinado.query('composto in ["9f80f3f77", "8b87a7a83"]')

# %%
x = teste.loc[:,'g0':'g10']
y = teste['composto'].map({'9f80f3f77': 0, '8b87a7a83': 1})

# %%
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

# %%
modelo_rlogistica3 = LogisticRegression(solver='newton-cg')
modelo_rlogistica3.fit(x_treino, y_treino)
modelo_rlogistica3.score(x_teste, y_teste)
# Out:
# 0.9444444444444444

# %% [markdown]
# ### Desafios 06: Resumo do que você aprendeu

# %% [markdown]
#  Nessa aula, aprendemos um pouco sobre a história do Machine Learning, como usá-lo para nos auxiliar. E também começamos a exploramos a biblioteca do Sklearn implementando alguns modelos treinando e testando.
